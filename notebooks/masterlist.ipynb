# %%
# %pwd
# Out:
# 'c:\\Users\\PrinciaFernandes\\Mresult\\Phenomix\\notebooks'

# %%
import os
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\PrinciaFernandes\\Mresult\\Phenomix'

# %%
import os
import json

def get_detail_files(dir:str)->list:
    detail_files = []
    websites = ['CPRD','HDRUK','OHDSI','PHEKB','SENTINEL']
    for files in os.listdir(dir):
        if files in websites:
            file_path = os.path.join(dir,files)
            for detail in os.listdir(file_path):
                if '_detail.json' in detail:
                    with open(os.path.join(file_path,detail),'r') as f:
                        file_content = f.read()
                    detail_files.extend(json.loads(file_content))
    return detail_files


def transform_detail(detail_files):
    new_detail = []
    for dict in detail_files:
        d = {}
        if 'Outcome' in dict.keys(): 
            d['Name'] = dict['Outcome']
        elif 'Disease' in dict.keys():
            d['Name'] = dict['Disease']
        elif "Cohort_name" in dict.keys():
            d['Name'] = dict["Cohort_name"]
        else:
            d['Name'] = dict['Name']
        if 'PID' in dict.keys():
            d['PID'] = dict['PID']
        new_detail.append(d)
    return new_detail


def get_pid_key(pid):
    keys = ['Phenotypes','hdruk_PID','phekb_PID','cprd_PID','Sentinel_PID','ohdsi_PID']
    key_map = {'H':keys[1],'P':keys[2],'C':keys[3],'S':keys[4],'O':keys[5]}
    init_pid = pid[0]
    if init_pid in key_map:
        return key_map[init_pid]


def create_masterlist(combined_detail):
    masterlist = []
    name_list = []
    keys = ['Phenotypes','hdruk_PID','phekb_PID','cprd_PID','Sentinel_PID','ohdsi_PID']

    for detail in combined_detail:
        if detail['Name'] not in name_list:
            name_list.append(detail['Name'])
            d = {k:None for k in keys}
            d[keys[0]] = detail['Name']
            pid_key = get_pid_key(detail['PID'])
            d[pid_key] = detail['PID']
            masterlist.append(d)
        else:

            pid_key = get_pid_key(detail['PID'])
            for d in masterlist:
                if d[keys[0]] == detail['Name']:
                    if not d[pid_key] is None:
                        d[pid_key] = d[pid_key] + f', {detail['PID']}' 
                    else:
                        d[pid_key] = detail['PID']
    sorted_masterlist = sorted(masterlist,key = lambda x:x['Phenotypes'])
    id = 0
    for d in sorted_masterlist:
        id += 1
        
        v1 = 'H' if d['hdruk_PID'] is not None else 'X'
        v2 = 'P' if d['phekb_PID'] is not None else 'X'
        v3 = 'C' if d['cprd_PID'] is not None else 'X'
        v4 = 'S' if d['Sentinel_PID'] is not None else 'X'
        v5 = 'O' if d['ohdsi_PID'] is not None else 'X'

        d['id'] = f'{v1}{v2}{v3}{v4}{v5}{id:04d}'
    
    return sorted_masterlist

# %%
from src.config import PROCESSED_DIR

# %%
def main():
    detail_files = get_detail_files(PROCESSED_DIR)
    # combined_detail = transform_detail(detail_files)
    # masterlist = create_masterlist(combined_detail)

    # with open('masterlist.json','w') as file:
    #     json.dump(masterlist,file,indent=4)

    # print("Masterlist saved successfully")
    return detail_files
f = main()

# %%
f
# Out:
# [{'Disease': 'Abdominal Aortic Aneurysm', 'Disease_num': 1, 'PID': 'CP000001'},
#  {'Disease': 'Abdominal Hernia', 'Disease_num': 2, 'PID': 'CP000002'},
#  {'Phenotype_id': 'PH1',
#   'Phenotype_version_id': 2,
#   'Name': 'COVID-19 infection',
#   'Defination': 'We ascertained people with a confirmed or suspected Covid-19 diagnosis as follows:\n\n\n1) a positive PCR or antigen test from the Covid-19 laboratory test data, with specimen date on or before 31 October 2020; or\n\n\n2) a Covid-19 diagnosis SNOMED-CT concept code appearing in the primary care data, with event date on or before 31 October; or\n\n\n3) a diagnosis ICD-10 code appearing in the hospital episodes (main or secondary diagnostic code position in the admitted patient care component of the hospital episode statistics), with admission date on or before 31 October or\n\n\n4) death registration with a mention (as underlying on contributing cause) of a diagnosis ICD-10 code , with death registration date on or before 31 October 2020.\n\n\n\n\n\n\n\n\n',
#   'Implementation': 'NA',
#   'Publications': 'NA',
#   'Validation': 'NA',
#   'Citation_requirements': 'NA',
#   'Created': '2021-10-06T15:58:48.523066Z',
#   'author': 'BHF CVD COVID UK Consortium',
#   'Collections': ['BHF Data Science Centre', 'Phenotype Library'],
#   'Tags': 'NA',
#   'Group': 'NA',
#   'Group_access': 1,
#   'World_access': 1,
#   'Updated': '2021-10-06T15:58:48.523092Z',
#   'Sex': 'Both',
#   'Type': 'Disease or syndrome',
#   'Phenoflow_id': 1,
#   'Data_sources': {'GPES Data for Pandemic Planning and Research (COVID-19)': 'https://web.www.healthdatagateway.org/dataset/696cfc9f-090d-4328-94ac-140760a77c73',
#    'Hospital Episode Statistics Admitted Patient Care': 'https://web.www.healthdatagateway.org/dataset/2b6409db-a669-4bef-9fd5-39c2b6f8d5e9',
#    'Civil Registration - Deaths': 'https://web.www.healthdatagateway.org/dataset/050163dc-1728-4ac5-a7d9-4dd3ca0ca12a',
#    'Covid-19 Second Generation Surveillance System': 'https://web.www.healthdatagateway.org/dataset/fede31c6-a9c5-4cfb-9866-9b58b2199cff'},
#   'Coding_system': 'ICD10 codes',
#   'Event_start_date': '2020-01-01T00:00:00.00Z',
#   'Event_end_date': '2020-10-31T00:00:00.00Z',
#   'Status': 2,
#   'Is_deleted': 'NA',
#   'Owner': 'ieuan.scanlon',
#   'PID': 'HP000001'},
#  {'Phenotype_id': 'PH10',
#   'Phenotype_version_id': 20,
#   'Name': 'Heart Rate',
#   'Defination': 'In the Clinical Practice Research Datalink (CPRD, primary care data) we extracted heart rate measurements using the structured data component of the additional CPRD table (entity type 131 / Pulse (CVS/BP)). Measurements were extracted from the data1 field.\n\n\n\n',
#   'Implementation': 'NA',
#   'Publications': 'NA',
#   'Validation': 'NA',
#   'Citation_requirements': 'NA',
#   'Created': '2021-10-06T15:59:13.917230Z',
#   'author': 'Archangelidi O',
#   'Collections': ['Phenotype Library'],
#   'Tags': 'NA',
#   'Group': 'NA',
#   'Group_access': 1,
#   'World_access': 1,
#   'Updated': '2021-10-06T15:59:13.917264Z',
#   'Sex': 'Both',
#   'Type': 'Biomarker',
#   'Phenoflow_id': 'NA',
#   'Data_sources': {'CPRD GOLD': 'https://web.www.healthdatagateway.org/dataset/a29feafa-7bdd-44e9-b977-c9d26425e67f'},
#   'Coding_system': 'NA',
#   'Event_start_date': '1999-01-01T00:00:00.00Z',
#   'Event_end_date': '2016-07-01T00:00:00.00Z',
#   'Status': 2,
#   'Is_deleted': 'NA',
#   'Owner': 'ieuan.scanlon',
#   'PID': 'HP000002'},
#  {'Phenotype_id': 'PH11',
#   'Phenotype_version_id': 22,
#   'Name': 'COPD',
#   'Defination': 'These codes are not intended to be mandatory, but are to be used as a starting point for the identification of COPD in routine EHR. Each study may differ in the sensitivity and specificity of the coding required.\n\n\nAccording to the National Institute for Health and Care Excellence (NICE) guidelines for the diagnosis of COPD, COPD should be suspected in patients over 35 years old who have a risk factor (typically smoking) and at least one symptom. It is therefore recommended that these codes are only utilised in an adult population at least 35 years old with a history of smoking.\n\n\nhttps://www.nice.org.uk/guidance/ng115/chapter/Recommendations#diagnosing-copd\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nValidation of Read Codes for the Identification of COPD in CPRD\n\n"Quint et al. validated a set of Read codes for the identification of COPD in CPRD in 2014. Using diagnostic codes alone, the positive predictive value (PPV) was 86.5% (77.5?92.3%). Requiring a diagnostic code, spirometry measures, and specific medication increased PPV to 89.4% (80.7?94.5%) but reduced\ncase numbers by 10%."\n\n\n\n\n\n',
#   'Implementation': 'NA',
#   'Publications': [{'doi': None,
#     'details': 'Publications in 2019 using validated Read codes from Quint et al. 2014'},
#    {'doi': None,
#     'details': 'D. Stolz, Kostikas, K., Loefroth, E., Fogel, R., Gutzwiller, F. S., Conti, V., Cao, H., and Clemens, A., ?Differences in COPD exacerbation risk between women and men: analysis from the UK Clinical Practice Research Datalink data?, Chest, 2019."'},
#    {'doi': None,
#     'details': 'M. Pikoula, Quint, J. K., Nissen, F., Hemingway, H., Smeeth, L., and Denaxas, S., ?Identifying clinically important COPD sub-types using data-driven approaches in primary care population based electronic health records?, BMC Med Inform Decis Mak, vol. 19, p. 86, 2019."'},
#    {'doi': None,
#     'details': 'H. R. Whittaker, Mullerova, H., Jarvis, D., Barnes, N. C., Jones, P. W., Compton, C. H., Kiddle, S. J., and Quint, J. K., ?Inhaled corticosteroids, blood eosinophils, and FEV1 decline in patients with COPD in a large UK primary health care setting?, Int J Chron Obstruct Pulmon Dis, vol. 14, pp. 1063-1073, 2019."'},
#    {'doi': None,
#     'details': 'C. I. Bloom, Ricciardi, F., Smeeth, L., Stone, P., and Quint, J. K., ?Predicting COPD 1-year mortality using prognostic predictors routinely measured in primary care?, BMC Med, vol. 17, p. 73, 2019."'},
#    {'doi': None,
#     'details': 'D. Dedman, Coton, S. J., Ghosh, R. E., Meeraus, W., Crim, C., Harvey, C., Amelio, J., and Landis, S. H., ?Treatment Patterns of New Users of Fluticasone Furoate/Vilanterol in Asthma and COPD in UK Primary Care: Retrospective Cohort Study?, Pulmonary Therapy, vol. 5, pp. 81-95, 2019."'},
#    {'doi': None,
#     'details': 'J. D. Chalmers, Poole, C., Webster, S., Tebboth, A., Dickinson, S., and Gayle, A., ?Assessing the healthcare resource use associated with inappropriate prescribing of inhaled corticosteroids for people with chronic obstructive pulmonary disease (COPD) in GOLD groups A or B: an observational study using the Clinical Practice Research Data?, Respir Res, vol. 19, p. 63, 2018."'},
#    {'doi': None, 'details': 'Publications in 2019 using Read codes from QOF'},
#    {'doi': None,
#     'details': 'P. Rockenschaub, Jhass, A., Freemantle, N., Aryee, A., Rafiq, M., Hayward, A., and Shallcross, L., ?Opportunities to reduce antibiotic prescribing for patients with COPD in primary care: a cohort study using electronic health records from the Clinical Practice Research Datalink (CPRD)?, J Antimicrob Chemother, 2019."'}],
#   'Validation': 'NA',
#   'Citation_requirements': 'NA',
#   'Created': '2021-10-06T15:59:19.788539Z',
#   'author': 'Eleanor L Axson, Jennifer K Quint',
#   'Collections': ['BREATHE', 'Phenotype Library'],
#   'Tags': 'NA',
#   'Group': 'NA',
#   'Group_access': 1,
#   'World_access': 1,
#   'Updated': '2021-10-06T15:59:19.788573Z',
#   'Sex': 'Both',
#   'Type': 'Disease or syndrome',
#   'Phenoflow_id': 37,
#   'Data_sources': {'CPRD GOLD': 'https://web.www.healthdatagateway.org/dataset/a29feafa-7bdd-44e9-b977-c9d26425e67f',
#    'CPRD Aurum': 'https://web.www.healthdatagateway.org/dataset/1d574c14-1af0-490d-9c4e-be88cfd0e345',
#    'HES Admitted Patient Care data for CPRD GOLD': 'https://web.www.healthdatagateway.org/dataset/4bcf64a6-f404-4ef4-ae6e-172512ab5f43',
#    'HES Admitted Patient Care data for CPRD Aurum': 'https://web.www.healthdatagateway.org/dataset/ed2de8fe-a204-4a4e-bcfa-9e3ad85e2fee',
#    'Death Registration data for CPRD GOLD': 'https://web.www.healthdatagateway.org/dataset/1d35e229-13eb-4be1-9dae-4752b6c27c4a',
#    'Death Registration data for CPRD Aurum': 'https://web.www.healthdatagateway.org/dataset/ad8f07ef-a984-449b-8a60-d1dd564cc36d',
#    'UK Biobank': 'https://web.www.healthdatagateway.org/dataset/439e71c7-33b5-4e85-98ce-4b068f2523ad'},
#   'Coding_system': 'ICD10 codes',
#   'Event_start_date': '2001-01-01T00:00:00.00Z',
#   'Event_end_date': '2019-12-31T00:00:00.00Z',
#   'Status': 2,
#   'Is_deleted': 'NA',
#   'Owner': 'ieuan.scanlon',
#   'PID': 'HP000003'},
#  {'Phenotype_id': 'PH12',
#   'Phenotype_version_id': 24,
#   'Name': 'Asthma',
#   'Defination': 'These codes will capture asthma ever, not just current asthma. These codes are not intended to be mandatory, but are to be used as a starting point for the identification of asthma in routine EHR. Each study may differ in the sensitivity and specificity of the coding required.\n\n\nFor those interested in further discrimination of asthma phenotypes, we refer you to Nissen et al. 2019.\n\n\nF. Nissen, Douglas, I. J., Mullerova, H., Pearce, N., Bloom, C. I., Smeeth, L., and Quint, J. K., ?Clinical profile of predefined asthma phenotypes in a large cohort of UK primary care patients (Clinical Practice Research Datalink)?, J Asthma Allergy, vol. 12, pp. 7-19, 2019.\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nValidation of Read Codes for the Identification of COPD in CPRD\n\nQuint et al. validated a set of Read codes for the identification of COPD in CPRD in 2014. Using diagnostic codes alone, the positive predictive value (PPV) was 86.5% (77.5?92.3%). Requiring a diagnostic code, spirometry measures, and specific medication increased PPV to 89.4% (80.7?94.5%) but reduced case numbers by 10%.\n\n\n\n\n\n',
#   'Implementation': 'NA',
#   'Publications': [{'doi': None,
#     'details': 'Publications from 2019 using validated Read codes from Nissen et al. 2017'},
#    {'doi': None,
#     'details': 'F. Nissen, Douglas, I. J., Mullerova, H., Pearce, N., Bloom, C. I., Smeeth, L., and Quint, J. K., ?Clinical profile of predefined asthma phenotypes in a large cohort of UK primary care patients (Clinical Practice Research Datalink)?, J Asthma Allergy, vol. 12, pp. 7-19, 2019."'},
#    {'doi': None,
#     'details': 'C. I. Bloom, Walker, S., and Quint, J. K., ?Inadequate specialist care referrals for high-risk asthma patients in the UK: an adult population-based cohort 2006-2017?, J Asthma, pp. 1-7, 2019."'},
#    {'doi': None,
#     'details': 'D. Dedman, Coton, S. J., Ghosh, R. E., Meeraus, W., Crim, C., Harvey, C., Amelio, J., and Landis, S. H., ?Treatment Patterns of New Users of Fluticasone Furoate/Vilanterol in Asthma and COPD in UK Primary Care: Retrospective Cohort Study?, Pulmonary Therapy, vol. 5, pp. 81-95, 2019."'},
#    {'doi': None,
#     'details': 'Publications from 2019 using Read codes from QOF'},
#    {'doi': None,
#     'details': 'P. Rockenschaub, Jhass, A., Freemantle, N., Aryee, A., Rafiq, M., Hayward, A., and Shallcross, L., ?Opportunities to reduce antibiotic prescribing for patients with COPD in primary care: a cohort study using electronic health records from the Clinical Practice Research Datalink (CPRD)?, J Antimicrob Chemother, 2019."'},
#    {'doi': None, 'details': 'Wellcome Open Research'},
#    {'doi': None, 'details': 'https://osf.io/kfz3n/'}],
#   'Validation': 'NA',
#   'Citation_requirements': 'NA',
#   'Created': '2021-10-06T15:59:27.174560Z',
#   'author': 'Eleanor L Axson, Jennifer K Quint',
#   'Collections': ['BREATHE', 'Phenotype Library'],
#   'Tags': 'NA',
#   'Group': 'NA',
#   'Group_access': 1,
#   'World_access': 1,
#   'Updated': '2021-10-06T15:59:27.174592Z',
#   'Sex': 'Both',
#   'Type': 'Disease or syndrome',
#   'Phenoflow_id': 40,
#   'Data_sources': {'CPRD GOLD': 'https://web.www.healthdatagateway.org/dataset/a29feafa-7bdd-44e9-b977-c9d26425e67f',
#    'CPRD Aurum': 'https://web.www.healthdatagateway.org/dataset/1d574c14-1af0-490d-9c4e-be88cfd0e345',
#    'HES Admitted Patient Care data for CPRD GOLD': 'https://web.www.healthdatagateway.org/dataset/4bcf64a6-f404-4ef4-ae6e-172512ab5f43',
#    'HES Admitted Patient Care data for CPRD Aurum': 'https://web.www.healthdatagateway.org/dataset/ed2de8fe-a204-4a4e-bcfa-9e3ad85e2fee',
#    'Death Registration data for CPRD GOLD': 'https://web.www.healthdatagateway.org/dataset/1d35e229-13eb-4be1-9dae-4752b6c27c4a',
#    'Death Registration data for CPRD Aurum': 'https://web.www.healthdatagateway.org/dataset/ad8f07ef-a984-449b-8a60-d1dd564cc36d',
#    'UK Biobank': 'https://web.www.healthdatagateway.org/dataset/439e71c7-33b5-4e85-98ce-4b068f2523ad'},
#   'Coding_system': 'ICD10 codes',
#   'Event_start_date': '2001-01-01T00:00:00.00Z',
#   'Event_end_date': '2019-12-31T00:00:00.00Z',
#   'Status': 2,
#   'Is_deleted': 'NA',
#   'Owner': 'ieuan.scanlon',
#   'PID': 'HP000004'},
#  {'Phenotype_id': 'PH13',
#   'Phenotype_version_id': 26,
#   'Name': 'Bronchiestasis',
#   'Defination': '\n\n\n\n\n\n\n\n\n\n',
#   'Implementation': 'NA',
#   'Publications': 'NA',
#   'Validation': 'NA',
#   'Citation_requirements': 'NA',
#   'Created': '2021-10-06T15:59:31.558162Z',
#   'author': 'Eleanor L Axson, Jennifer K Quint',
#   'Collections': ['BREATHE', 'Phenotype Library'],
#   'Tags': 'NA',
#   'Group': 'NA',
#   'Group_access': 1,
#   'World_access': 1,
#   'Updated': '2021-10-06T15:59:31.558195Z',
#   'Sex': 'Both',
#   'Type': 'Disease or syndrome',
#   'Phenoflow_id': 49,
#   'Data_sources': {'CPRD GOLD': 'https://web.www.healthdatagateway.org/dataset/a29feafa-7bdd-44e9-b977-c9d26425e67f',
#    'CPRD Aurum': 'https://web.www.healthdatagateway.org/dataset/1d574c14-1af0-490d-9c4e-be88cfd0e345',
#    'HES Admitted Patient Care data for CPRD GOLD': 'https://web.www.healthdatagateway.org/dataset/4bcf64a6-f404-4ef4-ae6e-172512ab5f43',
#    'HES Admitted Patient Care data for CPRD Aurum': 'https://web.www.healthdatagateway.org/dataset/ed2de8fe-a204-4a4e-bcfa-9e3ad85e2fee',
#    'Death Registration data for CPRD GOLD': 'https://web.www.healthdatagateway.org/dataset/1d35e229-13eb-4be1-9dae-4752b6c27c4a',
#    'Death Registration data for CPRD Aurum': 'https://web.www.healthdatagateway.org/dataset/ad8f07ef-a984-449b-8a60-d1dd564cc36d',
#    'UK Biobank': 'https://web.www.healthdatagateway.org/dataset/439e71c7-33b5-4e85-98ce-4b068f2523ad'},
#   'Coding_system': 'ICD10 codes',
#   'Event_start_date': '2001-01-01T00:00:00.00Z',
#   'Event_end_date': '2019-12-31T00:00:00.00Z',
#   'Status': 2,
#   'Is_deleted': 'NA',
#   'Owner': 'ieuan.scanlon',
#   'PID': 'HP000005'},
#  {'Phenotype_id': 'PH14',
#   'Phenotype_version_id': 28,
#   'Name': 'Cystic Fibrosis',
#   'Defination': '\n\n\n\n\n\n\n\n\n\n',
#   'Implementation': 'NA',
#   'Publications': 'NA',
#   'Validation': 'NA',
#   'Citation_requirements': 'NA',
#   'Created': '2021-10-06T15:59:36.578171Z',
#   'author': 'Eleanor L Axson, Jennifer K Quint',
#   'Collections': ['BREATHE', 'Phenotype Library'],
#   'Tags': 'NA',
#   'Group': 'NA',
#   'Group_access': 1,
#   'World_access': 1,
#   'Updated': '2021-10-06T15:59:36.578201Z',
#   'Sex': 'Both',
#   'Type': 'Disease or syndrome',
#   'Phenoflow_id': 52,
#   'Data_sources': {'CPRD GOLD': 'https://web.www.healthdatagateway.org/dataset/a29feafa-7bdd-44e9-b977-c9d26425e67f',
#    'CPRD Aurum': 'https://web.www.healthdatagateway.org/dataset/1d574c14-1af0-490d-9c4e-be88cfd0e345',
#    'HES Admitted Patient Care data for CPRD GOLD': 'https://web.www.healthdatagateway.org/dataset/4bcf64a6-f404-4ef4-ae6e-172512ab5f43',
#    'HES Admitted Patient Care data for CPRD Aurum': 'https://web.www.healthdatagateway.org/dataset/ed2de8fe-a204-4a4e-bcfa-9e3ad85e2fee',
#    'Death Registration data for CPRD GOLD': 'https://web.www.healthdatagateway.org/dataset/1d35e229-13eb-4be1-9dae-4752b6c27c4a',
#    'Death Registration data for CPRD Aurum': 'https://web.www.healthdatagateway.org/dataset/ad8f07ef-a984-449b-8a60-d1dd564cc36d',
#    'UK Biobank': 'https://web.www.healthdatagateway.org/dataset/439e71c7-33b5-4e85-98ce-4b068f2523ad'},
#   'Coding_system': 'ICD10 codes',
#   'Event_start_date': '2001-01-01T00:00:00.00Z',
#   'Event_end_date': '2019-12-31T00:00:00.00Z',
#   'Status': 2,
#   'Is_deleted': 'NA',
#   'Owner': 'ieuan.scanlon',
#   'PID': 'HP000006'},
#  {'Phenotype_id': 'PH15',
#   'Phenotype_version_id': 30,
#   'Name': 'Pneumonia',
#   'Defination': 'These codes will capture both community- and hospital-acquired pneumonia. These codes are not intended to be mandatory, but are to be used as a starting point for the identification of pneumonia in routine EHR. Each study may differ in the sensitivity and specificity of the coding required.\n\n\nDefining a community-acquired pneumonia occurrence in CPRD and HES, Millett et al. 2013 used the following algorithm:\n\n1) Pneumonia records wtihin 28 days of each other were considered to be separate consultations for the same illness\n2) First record of pneumonia was the index date\n3) End of a pneumonia occurrence was defined as 28 days after the last pneumonia code within the illness episode\n4) In HES, pneumonia coded as the primary diagnosis on the first day of a hospital admission\n\n\nDefining a hospital-acquired pneumonia occurrence in HES and CPRD, Millett et al. 2013 used the following algorithm:\n\n1) Pneumonia coded at any time beyond the first day of a hospital admission\n2) Using CPRD in conjunction with HES, pneumonia coded in CPRD within 14 days of a hospital admission (for any cause) was deemed hospital-acquired\n3) In CPRD, use of a hospital-acquired pneumonia code at any time during the pneumonia occurrence\n\n\nMillett, E. R., Quint, J. K., Smeeth, L., Daniel, R. M., & Thomas, S. L. (2013). Incidence of community-acquired lower respiratory tract infections and pneumonia among older adults in the United Kingdom: a population-based study. PLoS One, 8(9), e75131. doi:10.1371/journal.pone.0075131\n\n\nDefining a community-acquired pneumonia resulting in hospitalisation occurrence in HES, Hicks et al. 2016 used the following algorithm:\n\n1) In HES, hospital admission following A&E visit, where pneumonia was coded as the primary diagnosis within two days of admission\n\n\nDefining a hospital-acquired pneumonia occurrence in CPRD and HES, Hicks et al. 2016 used the following algorithm:\n\n1) Pneumonia diagnosis in HES >2 days after hospital admission\n2) Pneumonia diagnosed in CPRD within 7 days after hospital discharge\n\n\nHicks, B. M., Yin, H., Bladou, F., Ernst, P., & Azoulay, L. (2017). Androgen deprivation therapy for prostate cancer and the risk of hospitalisation for community-acquired pneumonia. Thorax, 72(7), 596-597. doi:10.1136/thoraxjnl-2016-209512\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n',
#   'Implementation': 'NA',
#   'Publications': [{'doi': None,
#     'details': 'Publications identifying pneumonia in CPRD and/or HES:'},
#    {'doi': '10.1371/journal.pone.0075131',
#     'details': 'Millett, E. R., Quint, J. K., Smeeth, L., Daniel, R. M., &amp; Thomas, S. L. (2013). Incidence of community-acquired lower respiratory tract infections and pneumonia among older adults in the United Kingdom: a population-based study. PLoS One, 8(9), e75131. doi:10.1371/journal.pone.0075131"'},
#    {'doi': '10.2147/COPD.S138435',
#     'details': 'Braeken, D. C., Rohde, G. G., Franssen, F. M., Driessen, J. H., van Staa, T. P., Souverein, P. C., . . . de Vries, F. (2017). Risk of community-acquired pneumonia in chronic obstructive pulmonary disease stratified by smoking status: a population-based cohort study in the United Kingdom. Int J Chron Obstruct Pulmon Dis, 12, 2425-2432. doi:10.2147/COPD.S138435"'},
#    {'doi': '10.1136/thoraxjnl-2016-209512',
#     'details': 'Hicks, B. M., Yin, H., Bladou, F., Ernst, P., &amp; Azoulay, L. (2017). Androgen deprivation therapy for prostate cancer and the risk of hospitalisation for community-acquired pneumonia. Thorax, 72(7), 596-597. doi:10.1136/thoraxjnl-2016-209512"'},
#    {'doi': '10.1017/S0950268819001559',
#     'details': 'Sun, X., Douiri, A., &amp; Gulliford, M. (2019). Pneumonia incidence trends in UK primary care from 2002 to 2017: population-based cohort study. Epidemiol Infect, 147, e263. doi:10.1017/S0950268819001559"'}],
#   'Validation': 'NA',
#   'Citation_requirements': 'NA',
#   'Created': '2021-10-06T15:59:45.086392Z',
#   'author': 'Eleanor L Axson, Jennifer K Quint',
#   'Collections': ['Phenotype Library'],
#   'Tags': 'NA',
#   'Group': 'NA',
#   'Group_access': 1,
#   'World_access': 1,
#   'Updated': '2021-10-06T15:59:45.086424Z',
#   'Sex': 'Both',
#   'Type': 'Disease or syndrome',
#   'Phenoflow_id': 58,
#   'Data_sources': {'CPRD GOLD': 'https://web.www.healthdatagateway.org/dataset/a29feafa-7bdd-44e9-b977-c9d26425e67f',
#    'CPRD Aurum': 'https://web.www.healthdatagateway.org/dataset/1d574c14-1af0-490d-9c4e-be88cfd0e345',
#    'HES Admitted Patient Care data for CPRD GOLD': 'https://web.www.healthdatagateway.org/dataset/4bcf64a6-f404-4ef4-ae6e-172512ab5f43',
#    'HES Admitted Patient Care data for CPRD Aurum': 'https://web.www.healthdatagateway.org/dataset/ed2de8fe-a204-4a4e-bcfa-9e3ad85e2fee',
#    'Death Registration data for CPRD GOLD': 'https://web.www.healthdatagateway.org/dataset/1d35e229-13eb-4be1-9dae-4752b6c27c4a',
#    'Death Registration data for CPRD Aurum': 'https://web.www.healthdatagateway.org/dataset/ad8f07ef-a984-449b-8a60-d1dd564cc36d',
#    'UK Biobank': 'https://web.www.healthdatagateway.org/dataset/439e71c7-33b5-4e85-98ce-4b068f2523ad'},
#   'Coding_system': 'ICD10 codes',
#   'Event_start_date': '2001-01-01T00:00:00.00Z',
#   'Event_end_date': '2019-12-31T00:00:00.00Z',
#   'Status': 2,
#   'Is_deleted': 'NA',
#   'Owner': 'ieuan.scanlon',
#   'PID': 'HP000007'},
#  {'Phenotype_id': 'PH16',
#   'Phenotype_version_id': 32,
#   'Name': 'Blood Pressure',
#   'Defination': 'Where multiple measurements were present in a single consultation (identified by the consid identifier) we calculated the average. We defined the range of plausible values as 20-350 mmHg for systolic measurements and 20-200 mmHg for diastolic measurements.\n\n\n\n\n\n\n',
#   'Implementation': 'NA',
#   'Publications': 'NA',
#   'Validation': 'NA',
#   'Citation_requirements': 'NA',
#   'Created': '2021-10-06T15:59:46.672724Z',
#   'author': 'Julie George, Emily Herrett, Liam Smeeth, Harry Hemingway, Anoop Shah, Spiros Denaxas',
#   'Collections': ['Phenotype Library'],
#   'Tags': 'NA',
#   'Group': 'NA',
#   'Group_access': 1,
#   'World_access': 1,
#   'Updated': '2021-10-06T15:59:46.672759Z',
#   'Sex': 'Both',
#   'Type': 'Biomarker',
#   'Phenoflow_id': 61,
#   'Data_sources': {'CPRD GOLD': 'https://web.www.healthdatagateway.org/dataset/a29feafa-7bdd-44e9-b977-c9d26425e67f'},
#   'Coding_system': 'Read codes v2',
#   'Event_start_date': '1999-01-01T00:00:00.00Z',
#   'Event_end_date': '2016-07-01T00:00:00.00Z',
#   'Status': 2,
#   'Is_deleted': 'NA',
#   'Owner': 'ieuan.scanlon',
#   'PID': 'HP000008'},
#  {'Phenotype_id': 'PH17',
#   'Phenotype_version_id': 34,
#   'Name': 'Body Mass Index',
#   'Defination': 'Measurements were extracted from the data3 field. Where multiple measurements were present in a single consultation (identified by the consid identifier) we calculated the average. We excluded measurements below 10 kg/m2 or above 80 kg/m2.\n\n\n\n',
#   'Implementation': 'NA',
#   'Publications': 'NA',
#   'Validation': 'NA',
#   'Citation_requirements': 'NA',
#   'Created': '2021-10-06T15:59:47.234695Z',
#   'author': 'Julie George, Emily Herrett, Liam Smeeth, Harry Hemingway, Anoop Shah, Spiros Denaxas',
#   'Collections': ['Phenotype Library'],
#   'Tags': 'NA',
#   'Group': 'NA',
#   'Group_access': 1,
#   'World_access': 1,
#   'Updated': '2021-10-06T15:59:47.234727Z',
#   'Sex': 'Both',
#   'Type': 'Biomarker',
#   'Phenoflow_id': 'NA',
#   'Data_sources': {'CPRD GOLD': 'https://web.www.healthdatagateway.org/dataset/a29feafa-7bdd-44e9-b977-c9d26425e67f'},
#   'Coding_system': 'NA',
#   'Event_start_date': '1999-01-01T00:00:00.00Z',
#   'Event_end_date': '2016-07-01T00:00:00.00Z',
#   'Status': 2,
#   'Is_deleted': 'NA',
#   'Owner': 'ieuan.scanlon',
#   'PID': 'HP000009'},
#  {'Phenotype_id': 'PH18',
#   'Phenotype_version_id': 36,
#   'Name': 'Marital status',
#   'Defination': '\n\n\n\n',
#   'Implementation': 'NA',
#   'Publications': [{'doi': '10.1093/eurheartj/eht533',
#     'details': 'Rapsomaniki E et al. Prognostic models for stable coronary artery disease based on electronic health record cohort of 102 023 patients. Eur Heart J. 2014 Apr;35(13):844-52. doi: 10.1093/eurheartj/eht533. Epub 2013 Dec 17. PMID: 24353280'}],
#   'Validation': 'NA',
#   'Citation_requirements': 'NA',
#   'Created': '2021-10-06T15:59:51.151730Z',
#   'author': 'CALIBER',
#   'Collections': ['Phenotype Library'],
#   'Tags': 'NA',
#   'Group': 'NA',
#   'Group_access': 1,
#   'World_access': 1,
#   'Updated': '2021-10-06T15:59:51.151771Z',
#   'Sex': 'Both',
#   'Type': 'Lifestyle risk factor',
#   'Phenoflow_id': 64,
#   'Data_sources': {'CPRD GOLD': 'https://web.www.healthdatagateway.org/dataset/a29feafa-7bdd-44e9-b977-c9d26425e67f'},
#   'Coding_system': 'Read codes v2',
#   'Event_start_date': '1999-01-01T00:00:00.00Z',
#   'Event_end_date': '2016-07-01T00:00:00.00Z',
#   'Status': 2,
#   'Is_deleted': 'NA',
#   'Owner': 'ieuan.scanlon',
#   'PID': 'HP000010'},
#  {'Phenotype_id': 'PH19',
#   'Phenotype_version_id': 38,
#   'Name': 'Anaphylaxis',
#   'Defination': '\n\n\n\n\n\n',
#   'Implementation': 'NA',
#   'Publications': 'NA',
#   'Validation': 'NA',
#   'Citation_requirements': 'NA',
#   'Created': '2021-10-06T15:59:52.787618Z',
#   'author': 'Cardoso V.,Nirantharakumar K.,Gkoutos G',
#   'Collections': ['Phenotype Library'],
#   'Tags': 'NA',
#   'Group': 'NA',
#   'Group_access': 1,
#   'World_access': 1,
#   'Updated': '2021-10-06T15:59:52.787652Z',
#   'Sex': 'Both',
#   'Type': 'Disease or syndrome',
#   'Phenoflow_id': 68,
#   'Data_sources': {'The Health Improvement Network (THIN)': '',
#    'Hospital Episode Statistics Admitted Patient Care': 'https://web.www.healthdatagateway.org/dataset/2b6409db-a669-4bef-9fd5-39c2b6f8d5e9'},
#   'Coding_system': 'ICD10 codes',
#   'Event_start_date': '1901-01-01T00:00:00.00Z',
#   'Event_end_date': '2019-12-31T00:00:00.00Z',
#   'Status': 2,
#   'Is_deleted': 'NA',
#   'Owner': 'ieuan.scanlon',
#   'PID': 'HP000011'},
#  {'Phenotype_id': 'PH2',
#   'Phenotype_version_id': 4,
#   'Name': 'Anxiety',
#   'Defination': 'Using electronic health records from 1714 UK general practices registered with the Clinical Practice\nResearch Datalink we examined incidence and event rates of depression and anxiety disorders, self-harm,\nprescriptions for antidepressants and benzodiazepines and GP referrals to mental health services per\n100,000 person-months, before, during and after the peak of the Covid-19 emergency. Analyses were\nstratified by gender, age group and practice-level Index of Multiple Deprivation quintile.\n\n\n\n\n\n\n\n\n',
#   'Implementation': 'NA',
#   'Publications': [{'doi': None,
#     'details': 'Matthew J Carr, Sarah Steeg, Roger T Webb, Nav Kapur, Carolyn A Chew-Graham, Kathrym M Abel, Holly Hope, Matthias Pierce, Darren M. Ashcroft, Primary care contact for mental illness and self-harm before during and after the peak of the Covid-19 pandemic in the UK: cohort study of 13 million individual". 2020.'}],
#   'Validation': 'NA',
#   'Citation_requirements': 'NA',
#   'Created': '2021-10-06T15:58:50.761328Z',
#   'author': 'Matthew J Carr, Sarah Steeg, Roger T Webb, Nav Kapur, Carolyn A Chew-Graham, Kathrym M Abel, Holly Hope, Matthias Pierce, Darren M. Ashcroft',
#   'Collections': ['Phenotype Library'],
#   'Tags': 'NA',
#   'Group': 'NA',
#   'Group_access': 1,
#   'World_access': 1,
#   'Updated': '2021-10-06T15:58:50.761354Z',
#   'Sex': 'Both',
#   'Type': 'Disease or syndrome',
#   'Phenoflow_id': 4,
#   'Data_sources': {'CPRD GOLD': 'https://web.www.healthdatagateway.org/dataset/a29feafa-7bdd-44e9-b977-c9d26425e67f',
#    'CPRD Aurum': 'https://web.www.healthdatagateway.org/dataset/1d574c14-1af0-490d-9c4e-be88cfd0e345'},
#   'Coding_system': 'Read codes v2',
#   'Event_start_date': '2010-01-01T00:00:00.00Z',
#   'Event_end_date': '2020-06-30T00:00:00.00Z',
#   'Status': 2,
#   'Is_deleted': 'NA',
#   'Owner': 'ieuan.scanlon',
#   'PID': 'HP000012'},
#  {'Phenotype_id': 'PH20',
#   'Phenotype_version_id': 40,
#   'Name': 'Hearing loss',
#   'Defination': '\n\n\n\n\n\n',
#   'Implementation': 'NA',
#   'Publications': 'NA',
#   'Validation': 'NA',
#   'Citation_requirements': 'NA',
#   'Created': '2021-10-06T15:59:55.480000Z',
#   'author': 'Cardoso V.,Nirantharakumar K.,Gkoutos G',
#   'Collections': ['Phenotype Library'],
#   'Tags': 'NA',
#   'Group': 'NA',
#   'Group_access': 1,
#   'World_access': 1,
#   'Updated': '2021-10-06T15:59:55.480033Z',
#   'Sex': 'Both',
#   'Type': 'Disease or syndrome',
#   'Phenoflow_id': 70,
#   'Data_sources': {'The Health Improvement Network (THIN)': '',
#    'Hospital Episode Statistics Admitted Patient Care': 'https://web.www.healthdatagateway.org/dataset/2b6409db-a669-4bef-9fd5-39c2b6f8d5e9'},
#   'Coding_system': 'ICD10 codes',
#   'Event_start_date': '1901-01-01T00:00:00.00Z',
#   'Event_end_date': '2019-12-31T00:00:00.00Z',
#   'Status': 2,
#   'Is_deleted': 'NA',
#   'Owner': 'ieuan.scanlon',
#   'PID': 'HP000013'},
#  {'Phenotype_id': 'PH3',
#   'Phenotype_version_id': 6,
#   'Name': 'Depression',
#   'Defination': 'Using electronic health records from 1714 UK general practices registered with the Clinical Practice\nResearch Datalink we examined incidence and event rates of depression and anxiety disorders, self-harm,\nprescriptions for antidepressants and benzodiazepines and GP referrals to mental health services per\n100,000 person-months, before, during and after the peak of the Covid-19 emergency. Analyses were\nstratified by gender, age group and practice-level Index of Multiple Deprivation quintile.\n\n\n\n\n\n\n\n\n',
#   'Implementation': 'NA',
#   'Publications': [{'doi': None,
#     'details': 'Matthew J Carr, Sarah Steeg, Roger T Webb, Nav Kapur, Carolyn A Chew-Graham, Kathrym M Abel, Holly Hope, Matthias Pierce, Darren M. Ashcroft, Primary care contact for mental illness and self-harm before during and after the peak of the Covid-19 pandemic in the UK: cohort study of 13 million individual". 2020.'}],
#   'Validation': 'NA',
#   'Citation_requirements': 'NA',
#   'Created': '2021-10-06T15:58:53.302473Z',
#   'author': 'Matthew J Carr, Sarah Steeg, Roger T Webb, Nav Kapur, Carolyn A Chew-Graham, Kathrym M Abel, Holly Hope, Matthias Pierce, Darren M. Ashcroft',
#   'Collections': ['Phenotype Library'],
#   'Tags': 'NA',
#   'Group': 'NA',
#   'Group_access': 1,
#   'World_access': 1,
#   'Updated': '2021-10-06T15:58:53.302500Z',
#   'Sex': 'Both',
#   'Type': 'Disease or syndrome',
#   'Phenoflow_id': 7,
#   'Data_sources': {'CPRD GOLD': 'https://web.www.healthdatagateway.org/dataset/a29feafa-7bdd-44e9-b977-c9d26425e67f',
#    'CPRD Aurum': 'https://web.www.healthdatagateway.org/dataset/1d574c14-1af0-490d-9c4e-be88cfd0e345'},
#   'Coding_system': 'Read codes v2',
#   'Event_start_date': '2010-01-01T00:00:00.00Z',
#   'Event_end_date': '2020-06-30T00:00:00.00Z',
#   'Status': 2,
#   'Is_deleted': 'NA',
#   'Owner': 'ieuan.scanlon',
#   'PID': 'HP000014'},
#  {'Phenotype_id': 'PH4',
#   'Phenotype_version_id': 8,
#   'Name': 'Self Harm',
#   'Defination': 'Using electronic health records from 1714 UK general practices registered with the Clinical Practice\nResearch Datalink we examined incidence and event rates of depression and anxiety disorders, self-harm,\nprescriptions for antidepressants and benzodiazepines and GP referrals to mental health services per\n100,000 person-months, before, during and after the peak of the Covid-19 emergency. Analyses were\nstratified by gender, age group and practice-level Index of Multiple Deprivation quintile.\n\n\n\n\n\n\n\n\n',
#   'Implementation': 'NA',
#   'Publications': [{'doi': None,
#     'details': 'Matthew J Carr, Sarah Steeg, Roger T Webb, Nav Kapur, Carolyn A Chew-Graham, Kathrym M Abel, Holly Hope, Matthias Pierce, Darren M. Ashcroft, Primary care contact for mental illness and self-harm before during and after the peak of the Covid-19 pandemic in the UK: cohort study of 13 million individual". 2020.'}],
#   'Validation': 'NA',
#   'Citation_requirements': 'NA',
#   'Created': '2021-10-06T15:59:01.792335Z',
#   'author': 'Matthew J Carr, Sarah Steeg, Roger T Webb, Nav Kapur, Carolyn A Chew-Graham, Kathrym M Abel, Holly Hope, Matthias Pierce, Darren M. Ashcroft',
#   'Collections': ['Phenotype Library'],
#   'Tags': 'NA',
#   'Group': 'NA',
#   'Group_access': 1,
#   'World_access': 1,
#   'Updated': '2021-10-06T15:59:01.792366Z',
#   'Sex': 'Both',
#   'Type': 'Disease or syndrome',
#   'Phenoflow_id': 13,
#   'Data_sources': {'CPRD GOLD': 'https://web.www.healthdatagateway.org/dataset/a29feafa-7bdd-44e9-b977-c9d26425e67f',
#    'CPRD Aurum': 'https://web.www.healthdatagateway.org/dataset/1d574c14-1af0-490d-9c4e-be88cfd0e345'},
#   'Coding_system': 'Read codes v2',
#   'Event_start_date': '2010-01-01T00:00:00.00Z',
#   'Event_end_date': '2020-06-30T00:00:00.00Z',
#   'Status': 2,
#   'Is_deleted': 'NA',
#   'Owner': 'ieuan.scanlon',
#   'PID': 'HP000015'},
#  {'Phenotype_id': 'PH5',
#   'Phenotype_version_id': 1509,
#   'Name': 'Cardiovascular Disease',
#   'Defination': 'Individuals entered the study from the latest of the following\ndates: \n\n1) the date of registration at a general practice plus 6 months\n2) the date for acceptable computer usage (quality measurement defined as the year in which a general practice continuously used their computer system for recording of medical events and prescribing) \n\n3) the date for acceptable mortality reporting (the date on which mortality recording reflected that of the United Kingdom general population) \n\n4) the date on which the individual turned 30 years of age \n\n\n   or \n\n5) January 1, 1997. Individuals exited the study at the earliest of the following dates:\n\n  \na) their first (i.e., “incident”) newly recorded CVD event\n\n\n  b) transfer out of the general practice; \n\n\n  c) their date of death; \n\n\n     or \n\n\n  d) January 18, 2016. The target population for which we wanted to estimate CVD risk included persons with general practice records and without a history of CVD or statin prescriptions\n\n\nA 2-stage approach to construct a dynamic risk prediction model, first modeling historical repeated risk factor measurements using multivariate mixed-effects linear models and then estimating 10-year CVD risk using Cox proportional hazards models\n\n\n\n\n\n\n\n\n',
#   'Implementation': 'NA',
#   'Publications': [{'doi': None,
#     'details': 'Ellie Paige, Jessica Barret, David Stevens, Ruth H Keog, Michael J Sweeting, Irwin Nazareth, Irene Petersen, Angela M Wood, "Landmark Models for Optimizing the Use of Repeated Measurements of Risk Factors in Electronic Health Records to Predict Future Disease Risk. American Journal of Epidemiology". 187(7), 1530-1538, 2018.'}],
#   'Validation': 'NA',
#   'Citation_requirements': 'NA',
#   'Created': '2021-10-06T15:59:02.372919Z',
#   'author': 'Ellie Paige, Jessica Barret, David Stevens, Ruth H Keog, Michael J Sweeting, Irwin Nazareth, Irene Petersen, Angela M Wood',
#   'Collections': ['Phenotype Library'],
#   'Tags': 'NA',
#   'Group': 'NA',
#   'Group_access': 1,
#   'World_access': 1,
#   'Updated': '2021-10-19T09:37:47.117155Z',
#   'Sex': 'Both',
#   'Type': 'Disease or syndrome',
#   'Phenoflow_id': 'NA',
#   'Data_sources': {'CPRD GOLD': 'https://web.www.healthdatagateway.org/dataset/a29feafa-7bdd-44e9-b977-c9d26425e67f'},
#   'Coding_system': 'Read codes v2',
#   'Event_start_date': '1997-01-01T00:00:00.00Z',
#   'Event_end_date': '2016-01-18T00:00:00.00Z',
#   'Status': 2,
#   'Is_deleted': 'NA',
#   'Owner': 'ieuan.scanlon',
#   'PID': 'HP000016'},
#  {'Phenotype_id': 'PH6',
#   'Phenotype_version_id': 12,
#   'Name': 'Cardiovascular Disease (Psoriasis Association Study with CVD)',
#   'Defination': 'The study population included patients with a first diagnosis of psoriasis between 1 January 1994 and 31 December 2009, who were 20 years or older at the time of the diagnosis. A comparison group of\nup to 5 controls per psoriasis patient was selected. Patients from both cohorts did not have any history of CVD or diabetes before the index date (first diagnosis of psoriasis) or corresponding consulting date\nand, in order to capture incident not prevalent cases of psoriasis or major CV events, all patients had to have at least 2 years prior registration within their general practice before entry into the study\ncohort. The control group consisted of patients who never received a diagnostic code for psoriasis. Controls were matched to psoriasis patients by age, gender, and general practice. We assigned control\npatients the same index date as the patients with psoriasis to whom they were matched. Person-time under observation for each patient was calculated from the corresponding index date up to the end of the study, which was the earliest date of the occurrence of a major\nCV event (MI, ACS, unstable angina, or stroke), transfer out of the practice, death date, end of follow-up (31 December 2011) or when the practice was no longer up to research data quality standards set by CPRD. Patient consent was not required; all patient data contained in CPRD is anonymised.\n\n\nPatients with psoriasis were included if they had their first diagnostic code for psoriasis during 1 January 1994–31 December 2009 and received a recognized treatment for psoriasis (emollients,\ntopical treatment, phototherapy, systemic therapy, or biologics (CG153 Psoriasis: NICE guideline; Samarasekera and Smith, 2014)). Patients were classified as having severe psoriasis once they had\nreceived a systemic treatment (acitretin, etretinate, ciclosporin, hydroxycarbamide, methotrexate, and fumaric acid), phototherapy, or a biologic therapy (etanercept, adalimumab, infliximab, ustekinumab,\nand efalizumab); alternatively they were classified as mild psoriasis.\n\n\n\n\n\n\n\n\n',
#   'Implementation': 'NA',
#   'Publications': [{'doi': None,
#     'details': 'Rosa Parisi, Martin K Rutter, Mark Lunt, Helen S. Young, Deborah P M Symmons, Christopher E M Griffiths, Darren M. Ashcroft, "Psoriasis and the Risk of Major Cardiovascular Events: Cohort Study Using the Clinical Practice Research Datalink". Journal of Investigative Dermatology, 135(9), 2189-2197, 2015.'}],
#   'Validation': 'NA',
#   'Citation_requirements': 'NA',
#   'Created': '2021-10-06T15:59:06.411029Z',
#   'author': 'Rosa Parisi, Martin K Rutter, Mark Lunt, Helen S Young, Deborah P M Symmons, Christopher E M Griffiths, Darren M Ashcroft',
#   'Collections': ['Phenotype Library'],
#   'Tags': 'NA',
#   'Group': 'NA',
#   'Group_access': 1,
#   'World_access': 1,
#   'Updated': '2021-10-06T15:59:06.411062Z',
#   'Sex': 'Both',
#   'Type': 'Disease or syndrome',
#   'Phenoflow_id': 'NA',
#   'Data_sources': {'CPRD GOLD': 'https://web.www.healthdatagateway.org/dataset/a29feafa-7bdd-44e9-b977-c9d26425e67f'},
#   'Coding_system': 'ICD10 codes',
#   'Event_start_date': '1994-01-01T00:00:00.00Z',
#   'Event_end_date': '2009-12-31T00:00:00.00Z',
#   'Status': 2,
#   'Is_deleted': 'NA',
#   'Owner': 'ieuan.scanlon',
#   'PID': 'HP000017'},
#  {'Phenotype_id': 'PH7',
#   'Phenotype_version_id': 14,
#   'Name': 'Psoriasis',
#   'Defination': 'The study population included patients with a first diagnosis of psoriasis between 1 January 1994 and 31 December 2009, who were 20 years or older at the time of the diagnosis. A comparison group of\nup to 5 controls per psoriasis patient was selected. Patients from both cohorts did not have any history of CVD or diabetes before the index date (first diagnosis of psoriasis) or corresponding consulting date\nand, in order to capture incident not prevalent cases of psoriasis or major CV events, all patients had to have at least 2 years prior registration within their general practice before entry into the study\ncohort. The control group consisted of patients who never received a diagnostic code for psoriasis. Controls were matched to psoriasis patients by age, gender, and general practice. We assigned control\npatients the same index date as the patients with psoriasis to whom they were matched. Person-time under observation for each patient was calculated from the corresponding index date up to the end of the study, which was the earliest date of the occurrence of a major\nCV event (MI, ACS, unstable angina, or stroke), transfer out of the practice, death date, end of follow-up (31 December 2011) or when the practice was no longer up to research data quality standards set by CPRD. Patient consent was not required; all patient data contained in CPRD is anonymised.\n\n\nPatients with psoriasis were included if they had their first diagnostic code for psoriasis during 1 January 1994–31 December 2009 and received a recognized treatment for psoriasis (emollients,\ntopical treatment, phototherapy, systemic therapy, or biologics (CG153 Psoriasis: NICE guideline; Samarasekera and Smith, 2014)). Patients were classified as having severe psoriasis once they had\nreceived a systemic treatment (acitretin, etretinate, ciclosporin, hydroxycarbamide, methotrexate, and fumaric acid), phototherapy, or a biologic therapy (etanercept, adalimumab, infliximab, ustekinumab,\nand efalizumab); alternatively they were classified as mild psoriasis.\n\n\n\n\n\n\n\n\n',
#   'Implementation': 'NA',
#   'Publications': [{'doi': None,
#     'details': 'Rosa Parisi, Martin K Rutter, Mark Lunt, Helen S. Young, Deborah P M Symmons, Christopher E M Griffiths, Darren M. Ashcroft, "Psoriasis and the Risk of Major Cardiovascular Events: Cohort Study Using the Clinical Practice Research Datalink". Journal of Investigative Dermatology, 135(9), 2189-2197, 2015.'}],
#   'Validation': 'NA',
#   'Citation_requirements': 'NA',
#   'Created': '2021-10-06T15:59:07.541835Z',
#   'author': 'Rosa Parisi, Martin K Rutter, Mark Lunt, Helen S Young, Deborah P M Symmons, Christopher E M Griffiths, Darren M Ashcroft',
#   'Collections': ['Phenotype Library'],
#   'Tags': 'NA',
#   'Group': 'NA',
#   'Group_access': 1,
#   'World_access': 1,
#   'Updated': '2021-10-06T15:59:07.541868Z',
#   'Sex': 'Both',
#   'Type': 'Disease or syndrome',
#   'Phenoflow_id': 21,
#   'Data_sources': {'CPRD GOLD': 'https://web.www.healthdatagateway.org/dataset/a29feafa-7bdd-44e9-b977-c9d26425e67f'},
#   'Coding_system': 'Read codes v2',
#   'Event_start_date': '1994-01-01T00:00:00.00Z',
#   'Event_end_date': '2009-12-31T00:00:00.00Z',
#   'Status': 2,
#   'Is_deleted': 'NA',
#   'Owner': 'ieuan.scanlon',
#   'PID': 'HP000018'},
#  {'Phenotype_id': 'PH8',
#   'Phenotype_version_id': 16,
#   'Name': 'Diabetes',
#   'Defination': 'In this retrospective cohort study, using the Clinical Practice\nResearch Datalink linked to hospital and death records for people in\nEngland, we identified 79 985 patients with incident type 2 diabetes\nmellitus (T2DM) between 2006 to 2013 matched to 386 547 patients\nwithout diabetes mellitus. Sex-stratified Cox models were used to assess\ncardiovascular risk.\n\n\n\n\n\n![img](/static/img/phenotypes/7/0.png)\n\n\n\n\n\n\n\n\n',
#   'Implementation': 'NA',
#   'Publications': [{'doi': None,
#     'details': 'Alison K Wright, Evangelos Kontopantelis, Richard Emsley, Iain Buchan, Mamas A. Mamas, Naveed Sattar, Darren M. Ashcroft, Martin K Rutter, "Cardiovascular Risk and Risk Factor Management in Type 2 Diabetes Mellitus: A Population-Based Cohort Study Assessing Sex Disparities". Circulation, 139(24), 2742-2753, 2019.  '}],
#   'Validation': 'NA',
#   'Citation_requirements': 'NA',
#   'Created': '2021-10-06T15:59:10.593545Z',
#   'author': 'Alison K Wright, Evangelos Kontopantelis, Richard Emsley, Iain Buchan, Mamas A Mamas, Naveed Sattar, Darren M Ashcroft, Martin K Rutter',
#   'Collections': ['Phenotype Library'],
#   'Tags': 'NA',
#   'Group': 'NA',
#   'Group_access': 1,
#   'World_access': 1,
#   'Updated': '2021-10-06T15:59:10.593580Z',
#   'Sex': 'Both',
#   'Type': 'Disease or syndrome',
#   'Phenoflow_id': 25,
#   'Data_sources': {'CPRD GOLD': 'https://web.www.healthdatagateway.org/dataset/a29feafa-7bdd-44e9-b977-c9d26425e67f'},
#   'Coding_system': 'Read codes v2',
#   'Event_start_date': '2006-01-01T00:00:00.00Z',
#   'Event_end_date': '2013-12-31T00:00:00.00Z',
#   'Status': 2,
#   'Is_deleted': 'NA',
#   'Owner': 'ieuan.scanlon',
#   'PID': 'HP000019'},
#  {'Phenotype_id': 'PH9',
#   'Phenotype_version_id': 1510,
#   'Name': 'Alcohol Consumption',
#   'Defination': '\n\n\n\n![img](/static/img/phenotypes/8/0.png)\n\n\nThe most recent alcohol consumption record in the\nfive years before entry into the study was used to classify participants drinking behaviour. In light of\ncurrent debates on the U/J-shaped relationship observed between alcohol consumption and aggregated\nCVD outcomes10 five drinking categories were defined including: (1) non-drinkers (Read66 codes such\nas "tee-total" and "non-drinkers"), former drinkers (those with codes for "stopped drinking alcohol"\n\nand/or "ex-drinker"), occasional drinkers (those with codes for "drinks rarely" and/or "drinks\noccasionally"), current moderate drinkers (those who had a code for current alcohol consumer and an\nindicator of whether they drank within daily [32g or 24g of alcohol for men and women respectively]\n\nand/or weekly [168g of alcohol for men and 112g for women] recommended sensible drinking limits\nfor the UK at the time of observation69) and current heavy drinkers (defined as those who exceeded\ndaily and/or weekly sensible drinking limits). We also utilised data fields with information entered on\ndaily and/or weekly amount of alcohol consumed to define participants as non-drinkers, moderate\ndrinkers (drank within daily and/or weekly guidelines) and heavy drinkers. Weekly alcohol data was\navailable as a continuous variable, so we were able to classify consumption using standard thresholds\n\n\nData on daily alcohol intake was entered using categories of: (1) < 1\nUK unit (8 grams of ethanol), (2) 1-2 UK units, (3) 3-6 UK units, (4) 7-9 UK units, and (5) > 9 UK\nunits [Read codes 1362.00-1366.00], for which we defined moderate drinking as anything >1 UK\n\nunit but less than 3 (women) or 7 (men) UK units. Unfortunately information on binge drinking was\nonly available for a select minority of the cohort (~100 people) therefore a separate category for this\ndrinking behaviour was not defined (but these patients were coded as heavy drinkers). We reclassified\nnon-drinkers as former drinkers if they had any record of drinking recorded in their entire clinical\nrecord entered on CPRD prior to study entry (in cases whereby non-drinkers had no record of\ndrinking before entering the study we assumed that they were not former drinkers). This resulted in\n19,853 (out of 184,747; 10.7%) non-drinkers being recoded as former drinkers, a further 6,826 (3.7%)\n\nparticipants were reclassified through having a positive history of alcohol abuse.\n\n\n\n\nIn the Clinical Practice Research Datalink (CPRD, primary care data) we extracted information on alcohol consumption based on:\n\n- Clinician-recorded alcohol consumption information\n  - Stuctured data elements related to daily/weekly alcohol unit consumption\n  - Evidence of alcohol abuse\n  - Evidence of alcohol-related harm\n\n\n\n\n\nWe extracted alcohol unit intake information using the structured data part (entity type 5) of the additional table (units recorded in data2) field. We additionally extract information on intake through clinician-recorded classifications using Read terms (see below).\n\n\n\n\n\n\n\n',
#   'Implementation': 'NA',
#   'Publications': [{'doi': '10.1136/bmjopen-2017-018331',
#     'details': 'Gho JMIH et al. An electronic health records cohort study on heart failure following myocardial infarction in England: incidence and predictors. BMJ Open. 2018 Mar 3;8(3):e018331. doi: 10.1136/bmjopen-2017-018331. PMID: 29502083'},
#    {'doi': '10.1371/journal.pone.0202344',
#     'details': 'Steele AJ et al. Machine learning models in electronic health records can outperform conventional survival models for predicting patient mortality in coronary artery disease. PLoS One. 2018 Aug 31;13(8):e0202344. doi: 10.1371/journal.pone.0202344. eCollection 2018. PMID: 30169498'},
#    {'doi': '10.1177/2047487318785228',
# ...
#   'Continous_observation_window_prior': 0,
#   'Continous_observation_window_post': 0,
#   'Number_of_concept_sets': 2,
#   'Demographic_criteria': 1,
#   'Demographic_criteria_age': 1,
#   'Demographic_criteria_gender': 0,
#   'Use_of_observation_period_inclusion_rule': 0,
#   'Restricted_by_visit': False,
#   'Has_washout_in_text': 0,
#   'Domain_condition_occurrence': 0,
#   'Domain_measurement': 0,
#   'Event_cohort': 0,
#   'Domain_observation': 0,
#   'Domain_visit_occurrence': 0,
#   'Domain_death': 0,
#   'Domain_drug_exposure': 0,
#   'Criteria_location_age_primary_criteria': 0,
#   'Domain_device_exposure': 0,
#   'Domain_procedure_occurrence': 1,
#   'Criteria_location_first_primary_criteria': 0,
#   'Criteria_location_age_inclusion_rules': 1,
#   'Criteria_location_visit_type_primary_criteria': 0,
#   'Criteria_location_first_inclusion_rules': 0,
#   'Criteria_location_gender_primary_criteria': 0,
#   'Criteria_location_condition_source_concept_primary_criteria': 0,
#   'Criteria_location_gender_inclusion_rules': 0,
#   'Criteria_location_provider_specialty_inclusion_rules': 0,
#   'Criteria_location_visit_source_concept_primary_criteria': 0,
#   'Criteria_location_condition_source_concept_inclusion_rules': 0,
#   'Criteria_location_provider_specialty_primary_criteria': 0,
#   'Domain_drug_era': 0,
#   'Criteria_location_procedure_source_concept_primary_criteria': 1,
#   'Exit_surveillance_window': 0,
#   'Domain_observation_period': 0,
#   'Criteria_location_age_additional_criteria': 0,
#   'Criteria_location_gender_additional_criteria': 0,
#   'Criteria_location_measurement_source_concept_primary_criteria': 0,
#   'Added_date': '2024-01-05T00:00:00.000Z',
#   'Updated_date': '2024-01-05T00:00:00.000Z',
#   'Added_version': 'NA',
#   'Replaces': None,
#   'Exit_drug_code_set_id': None,
#   'Exit_persistence_window': None,
#   'PID': 'OP000596'},
#  {'Cohort_id': 1313,
#   'Cohort_name': 'Nephrectomy, adults, post op new Afib',
#   'Cohort_name_formatted': 'Nephrectomy, adults, post op new Afib',
#   'Librarian': 'rao@ohdsi.org',
#   'Status': 'Pending peer review',
#   'Logic_description': 'NA',
#   'Hash_tag': ['#Surgery', ' #WorkGroup'],
#   'Is_circe_json': True,
#   'Contributors': ['Evan Minty'],
#   'Contributor_orcids': ['0000-0003-4631-9992'],
#   'Contributor_organizations': ["'OHDSI'"],
#   'Peer_reviewers': 'NA',
#   'Peer_reviewer_orcids': 0,
#   'Recommended_referent_concept_ids': 'NA',
#   'Ohdsi_forum_post': 'NA',
#   'Created_date': '2024-01-05T00:00:00.000Z',
#   'Modified_date': '2024-01-05T00:00:00.000Z',
#   'Last_modified_by': 0,
#   'Notes': 'NA',
#   'Is_reference_cohort': False,
#   'Censor_window_start_date': 0,
#   'Censor_window_end_date': 0,
#   'Collapse_settings_type': 'ERA',
#   'Collapse_era_pad': 0,
#   'Exit_strategy': 'end of continuous observation',
#   'Exit_date_off_set_field': 'NA',
#   'Exit_date_off_set': None,
#   'Number_of_inclusion_rules': 3,
#   'Initial_event_limit': 'First',
#   'Initial_event_restriction_additional_criteria': True,
#   'Initial_event_restriction_additional_criteria_limit': 'All',
#   'Inclusion_rule_qualifying_event_limit': 'First',
#   'Number_of_cohort_entry_events': 2,
#   'Number_of_domains_in_entry_events': 1,
#   'Domains_in_entry_events': ['ProcedureOccurrence'],
#   'Continous_observation_window_prior': 0,
#   'Continous_observation_window_post': 0,
#   'Number_of_concept_sets': 2,
#   'Demographic_criteria': 1,
#   'Demographic_criteria_age': 1,
#   'Demographic_criteria_gender': 0,
#   'Use_of_observation_period_inclusion_rule': 0,
#   'Restricted_by_visit': False,
#   'Has_washout_in_text': 0,
#   'Domain_condition_occurrence': 0,
#   'Domain_measurement': 0,
#   'Event_cohort': 0,
#   'Domain_observation': 0,
#   'Domain_visit_occurrence': 0,
#   'Domain_death': 0,
#   'Domain_drug_exposure': 0,
#   'Criteria_location_age_primary_criteria': 0,
#   'Domain_device_exposure': 0,
#   'Domain_procedure_occurrence': 1,
#   'Criteria_location_first_primary_criteria': 0,
#   'Criteria_location_age_inclusion_rules': 1,
#   'Criteria_location_visit_type_primary_criteria': 0,
#   'Criteria_location_first_inclusion_rules': 0,
#   'Criteria_location_gender_primary_criteria': 0,
#   'Criteria_location_condition_source_concept_primary_criteria': 0,
#   'Criteria_location_gender_inclusion_rules': 0,
#   'Criteria_location_provider_specialty_inclusion_rules': 0,
#   'Criteria_location_visit_source_concept_primary_criteria': 0,
#   'Criteria_location_condition_source_concept_inclusion_rules': 0,
#   'Criteria_location_provider_specialty_primary_criteria': 0,
#   'Domain_drug_era': 0,
#   'Criteria_location_procedure_source_concept_primary_criteria': 1,
#   'Exit_surveillance_window': 0,
#   'Domain_observation_period': 0,
#   'Criteria_location_age_additional_criteria': 0,
#   'Criteria_location_gender_additional_criteria': 0,
#   'Criteria_location_measurement_source_concept_primary_criteria': 0,
#   'Added_date': '2024-01-05T00:00:00.000Z',
#   'Updated_date': '2024-01-05T00:00:00.000Z',
#   'Added_version': 'NA',
#   'Replaces': None,
#   'Exit_drug_code_set_id': None,
#   'Exit_persistence_window': None,
#   'PID': 'OP000597'},
#  {'Cohort_id': 1314,
#   'Cohort_name': 'Coronary Artery Bypass Graft, adults, post op new Afib',
#   'Cohort_name_formatted': 'Coronary Artery Bypass Graft, adults, post op new Afib',
#   'Librarian': 'rao@ohdsi.org',
#   'Status': 'Pending peer review',
#   'Logic_description': 'NA',
#   'Hash_tag': ['#Surgery', ' #WorkGroup'],
#   'Is_circe_json': True,
#   'Contributors': ['Evan Minty'],
#   'Contributor_orcids': ['0000-0003-4631-9992'],
#   'Contributor_organizations': ["'OHDSI'"],
#   'Peer_reviewers': 'NA',
#   'Peer_reviewer_orcids': 0,
#   'Recommended_referent_concept_ids': 'NA',
#   'Ohdsi_forum_post': 'NA',
#   'Created_date': '2024-01-05T00:00:00.000Z',
#   'Modified_date': '2024-01-05T00:00:00.000Z',
#   'Last_modified_by': 0,
#   'Notes': 'NA',
#   'Is_reference_cohort': False,
#   'Censor_window_start_date': 0,
#   'Censor_window_end_date': 0,
#   'Collapse_settings_type': 'ERA',
#   'Collapse_era_pad': 0,
#   'Exit_strategy': 'end of continuous observation',
#   'Exit_date_off_set_field': 'NA',
#   'Exit_date_off_set': None,
#   'Number_of_inclusion_rules': 3,
#   'Initial_event_limit': 'First',
#   'Initial_event_restriction_additional_criteria': True,
#   'Initial_event_restriction_additional_criteria_limit': 'All',
#   'Inclusion_rule_qualifying_event_limit': 'First',
#   'Number_of_cohort_entry_events': 2,
#   'Number_of_domains_in_entry_events': 1,
#   'Domains_in_entry_events': ['ProcedureOccurrence'],
#   'Continous_observation_window_prior': 0,
#   'Continous_observation_window_post': 0,
#   'Number_of_concept_sets': 2,
#   'Demographic_criteria': 1,
#   'Demographic_criteria_age': 1,
#   'Demographic_criteria_gender': 0,
#   'Use_of_observation_period_inclusion_rule': 0,
#   'Restricted_by_visit': False,
#   'Has_washout_in_text': 0,
#   'Domain_condition_occurrence': 0,
#   'Domain_measurement': 0,
#   'Event_cohort': 0,
#   'Domain_observation': 0,
#   'Domain_visit_occurrence': 0,
#   'Domain_death': 0,
#   'Domain_drug_exposure': 0,
#   'Criteria_location_age_primary_criteria': 0,
#   'Domain_device_exposure': 0,
#   'Domain_procedure_occurrence': 1,
#   'Criteria_location_first_primary_criteria': 0,
#   'Criteria_location_age_inclusion_rules': 1,
#   'Criteria_location_visit_type_primary_criteria': 0,
#   'Criteria_location_first_inclusion_rules': 0,
#   'Criteria_location_gender_primary_criteria': 0,
#   'Criteria_location_condition_source_concept_primary_criteria': 0,
#   'Criteria_location_gender_inclusion_rules': 0,
#   'Criteria_location_provider_specialty_inclusion_rules': 0,
#   'Criteria_location_visit_source_concept_primary_criteria': 0,
#   'Criteria_location_condition_source_concept_inclusion_rules': 0,
#   'Criteria_location_provider_specialty_primary_criteria': 0,
#   'Domain_drug_era': 0,
#   'Criteria_location_procedure_source_concept_primary_criteria': 1,
#   'Exit_surveillance_window': 0,
#   'Domain_observation_period': 0,
#   'Criteria_location_age_additional_criteria': 0,
#   'Criteria_location_gender_additional_criteria': 0,
#   'Criteria_location_measurement_source_concept_primary_criteria': 0,
#   'Added_date': '2024-01-05T00:00:00.000Z',
#   'Updated_date': '2024-01-05T00:00:00.000Z',
#   'Added_version': 'NA',
#   'Replaces': None,
#   'Exit_drug_code_set_id': None,
#   'Exit_persistence_window': None,
#   'PID': 'OP000598'},
#  {'Cohort_id': 1315,
#   'Cohort_name': 'Cardiac Valve Surgery, adults, post op new Afib',
#   'Cohort_name_formatted': 'Cardiac Valve Surgery, adults, post op new Afib',
#   'Librarian': 'rao@ohdsi.org',
#   'Status': 'Pending peer review',
#   'Logic_description': 'NA',
#   'Hash_tag': ['#Surgery', ' #WorkGroup'],
#   'Is_circe_json': True,
#   'Contributors': ['Evan Minty'],
#   'Contributor_orcids': ['0000-0003-4631-9992'],
#   'Contributor_organizations': ["'OHDSI'"],
#   'Peer_reviewers': 'NA',
#   'Peer_reviewer_orcids': 0,
#   'Recommended_referent_concept_ids': 'NA',
#   'Ohdsi_forum_post': 'NA',
#   'Created_date': '2024-01-05T00:00:00.000Z',
#   'Modified_date': '2024-01-05T00:00:00.000Z',
#   'Last_modified_by': 0,
#   'Notes': 'NA',
#   'Is_reference_cohort': False,
#   'Censor_window_start_date': 0,
#   'Censor_window_end_date': 0,
#   'Collapse_settings_type': 'ERA',
#   'Collapse_era_pad': 0,
#   'Exit_strategy': 'end of continuous observation',
#   'Exit_date_off_set_field': 'NA',
#   'Exit_date_off_set': None,
#   'Number_of_inclusion_rules': 3,
#   'Initial_event_limit': 'First',
#   'Initial_event_restriction_additional_criteria': True,
#   'Initial_event_restriction_additional_criteria_limit': 'All',
#   'Inclusion_rule_qualifying_event_limit': 'First',
#   'Number_of_cohort_entry_events': 2,
#   'Number_of_domains_in_entry_events': 1,
#   'Domains_in_entry_events': ['ProcedureOccurrence'],
#   'Continous_observation_window_prior': 0,
#   'Continous_observation_window_post': 0,
#   'Number_of_concept_sets': 2,
#   'Demographic_criteria': 1,
#   'Demographic_criteria_age': 1,
#   'Demographic_criteria_gender': 0,
#   'Use_of_observation_period_inclusion_rule': 0,
#   'Restricted_by_visit': False,
#   'Has_washout_in_text': 0,
#   'Domain_condition_occurrence': 0,
#   'Domain_measurement': 0,
#   'Event_cohort': 0,
#   'Domain_observation': 0,
#   'Domain_visit_occurrence': 0,
#   'Domain_death': 0,
#   'Domain_drug_exposure': 0,
#   'Criteria_location_age_primary_criteria': 0,
#   'Domain_device_exposure': 0,
#   'Domain_procedure_occurrence': 1,
#   'Criteria_location_first_primary_criteria': 0,
#   'Criteria_location_age_inclusion_rules': 1,
#   'Criteria_location_visit_type_primary_criteria': 0,
#   'Criteria_location_first_inclusion_rules': 0,
#   'Criteria_location_gender_primary_criteria': 0,
#   'Criteria_location_condition_source_concept_primary_criteria': 0,
#   'Criteria_location_gender_inclusion_rules': 0,
#   'Criteria_location_provider_specialty_inclusion_rules': 0,
#   'Criteria_location_visit_source_concept_primary_criteria': 0,
#   'Criteria_location_condition_source_concept_inclusion_rules': 0,
#   'Criteria_location_provider_specialty_primary_criteria': 0,
#   'Domain_drug_era': 0,
#   'Criteria_location_procedure_source_concept_primary_criteria': 1,
#   'Exit_surveillance_window': 0,
#   'Domain_observation_period': 0,
#   'Criteria_location_age_additional_criteria': 0,
#   'Criteria_location_gender_additional_criteria': 0,
#   'Criteria_location_measurement_source_concept_primary_criteria': 0,
#   'Added_date': '2024-01-05T00:00:00.000Z',
#   'Updated_date': '2024-01-05T00:00:00.000Z',
#   'Added_version': 'NA',
#   'Replaces': None,
#   'Exit_drug_code_set_id': None,
#   'Exit_persistence_window': None,
#   'PID': 'OP000599'},
#  {'Phenotype_id': 97,
#   'Name': 'Abdominal Aortic Aneurysm ( AAA )',
#   'Description': 'The algorithm uses Structured Query Language to identify AAA cases, controls, and excludes from the Electronic Medical Record. AAA cases were defined as meeting at least one of three criteria: had a AAA repair procedure (Case Type 1), had at least one vascular clinic encounter with a diagnosis of ruptured AAA (Case Type 2), or had at least two vascular clinic encounters with a diagnosis of unruptured AAA (Case Type 3). AAA controls must be neither excludes nor cases, had an encounter within the past 5 years, and never had a diagnosis of ICD9 code 441.3, 441.4, or 441.9 from any department. Patients were excluded if any exclusion diagnosis existed in the medical record, were younger than 40 or older than 89, were neither a Case Type 1 nor Case Type 2 and haven’t had an encounter within the past 5 years, or were not a case and had an ICD9 code diagnosis of 441.* at some point in the medical history.',
#   'Status': 'Final',
#   'Type_of_phenotype': 'Disease or Syndrome',
#   'Phenotype_attributes': 'CPT Codes, ICD 9 Codes, Vital Signs',
#   'Authors': 'Kenneth Borthwick',
#   'Files': {'AAA_Flowchart_v20120815.pdf': 'https://phekb.org/sites/phenotype/files/AAA_Flowchart_v20120815.pdf',
#    'Geisinger_AAA_Algorithm_Pseudocode_Final20120815.pdf': 'https://phekb.org/sites/phenotype/files/Geisinger_AAA_Algorithm_Pseudocode_Final20120815_0.pdf',
#    'Geisinger_AAA_Medications_v20120815.xlsx': 'https://phekb.org/sites/phenotype/files/Geisinger_AAA_Medications_v20120815.xlsx',
#    'Geisinger_AAA_ClinicalVariablesForGWAS_V20120920.xlsx': 'https://phekb.org/sites/phenotype/files/Geisinger_AAA_ClinicalVariablesForGWAS_V20120920.xlsx'},
#   'Institutions': 'Geisinger',
#   'Ages': 'Adult, Geriatric',
#   'Races': 'Caucasian (European)',
#   'Genders': 'Female, Male',
#   'Networks': 'eMERGE',
#   'Date_created': '2012-06-05T00:00:00.000Z',
#   'PID': 'PP000001'},
#  {'Phenotype_id': 90,
#   'Name': 'ACE Inhibitor (ACE-I) induced cough',
#   'Description': 'ACE-I induced cough is a common side effect of use of ACE inhibitors, one of the most common class of antihypertensives.\xa0 The frequency of ACEI-induced cough varies based on ancestry. \xa0A GWAS of ACEI cough using this algorithm in the eMERGE Network identifiedKCNIP4as associated with this phenotype, which was validated in two replication cohorts.Cases are those with ACEI cough. \xa0Controls are those exposed to ACEI without adverse events noted and not switched to angiotensin receptor blockers (ARBs).Algorithm validated - December 12, 2012.',
#   'Status': 'Final',
#   'Type_of_phenotype': 'Drug Response - adverse effect or efficacy',
#   'Phenotype_attributes': 'CPT Codes, ICD 9 Codes, Medications, Natural Language Processing',
#   'Authors': 'Jonathan Mosley and Josh Denny',
#   'Files': {'Data Dictionary for ACEi Cough': 'https://phekb.org/sites/phenotype/files/ACEiCough_Data_Dictionary_VU_final.xls',
#    'ACEi_cough_validation_guidelines_v3.doc': 'https://phekb.org/sites/phenotype/files/ACEi_cough_validation_guidelines_v3.doc',
#    'Ace inhibitor algorithm-2012-11-20.doc': 'https://phekb.org/sites/phenotype/files/Ace%20inhibitor%20algorithm-2012-11-20.doc',
#    'validation spreadsheet.xls': 'https://phekb.org/sites/phenotype/files/validation%20spreadsheet.xls'},
#   'Institutions': 'Vanderbilt University',
#   'Ages': 'Adult',
#   'Races': 'NA',
#   'Genders': 'Female, Male',
#   'Networks': 'eMERGE',
#   'Date_created': '2012-04-18T00:00:00.000Z',
#   'PID': 'PP000002'},
#  {'Outcome': 'Thromboembolic stroke',
#   'Title': 'Thromboembolic Stroke Algorithm Defined in Thromboembolic Stroke, Intracranial Hemorrhage, Gastrointestinal Bleeding, and Major Extracranial Bleeding Following Apixaban, Dabigatran, and Rivaroxaban Use in Patients Aged 64 Years and Younger with Atrial Fibrillation: An Inverse Probability of Treatment Weighting Analysis',
#   'Request_id': 'cder_mpl2p_wp039, cder_mpl2p_wp044, cder_mpl2p_wp047',
#   'Query_start_date': '2010-10-19T00:00:00.00Z',
#   'Query_end_date': '2022-02-28T00:00:00.00Z',
#   'Description': 'This report lists International Classification of Diseases, Ninth and Tenth Revisions, Clinical Modification (ICD-9-CM and ICD-10-CM) diagnosis codes and algorithms used to define thromboembolic stroke in this request.',
#   'Algorithm_to_define_outcome': 'The thromboembolic stroke outcome is defined as evidence of an ICD-9-CM or ICD-10-CM diagnosis code Outcome from Code List 1 that is the primary diagnosis from an inpatient encounter.',
#   'Request_send_date': '2022-11-15T00:00:00.00Z, 2023-03-20T00:00:00.00Z, 2023-07-07T00:00:00.00Z',
#   'PID': 'SP000001'}]

# %%
combined_detail = transform_detail(f)

# %%
combined_detail
# Out:
# [{'Name': 'Abdominal Aortic Aneurysm', 'PID': 'CP000001'},
#  {'Name': 'Abdominal Hernia', 'PID': 'CP000002'},
#  {'Name': 'COVID-19 infection', 'PID': 'HP000001'},
#  {'Name': 'Heart Rate', 'PID': 'HP000002'},
#  {'Name': 'COPD', 'PID': 'HP000003'},
#  {'Name': 'Asthma', 'PID': 'HP000004'},
#  {'Name': 'Bronchiestasis', 'PID': 'HP000005'},
#  {'Name': 'Cystic Fibrosis', 'PID': 'HP000006'},
#  {'Name': 'Pneumonia', 'PID': 'HP000007'},
#  {'Name': 'Blood Pressure', 'PID': 'HP000008'},
#  {'Name': 'Body Mass Index', 'PID': 'HP000009'},
#  {'Name': 'Marital status', 'PID': 'HP000010'},
#  {'Name': 'Anaphylaxis', 'PID': 'HP000011'},
#  {'Name': 'Anxiety', 'PID': 'HP000012'},
#  {'Name': 'Hearing loss', 'PID': 'HP000013'},
#  {'Name': 'Depression', 'PID': 'HP000014'},
#  {'Name': 'Self Harm', 'PID': 'HP000015'},
#  {'Name': 'Cardiovascular Disease', 'PID': 'HP000016'},
#  {'Name': 'Cardiovascular Disease (Psoriasis Association Study with CVD)',
#   'PID': 'HP000017'},
#  {'Name': 'Psoriasis', 'PID': 'HP000018'},
#  {'Name': 'Diabetes', 'PID': 'HP000019'},
#  {'Name': 'Alcohol Consumption', 'PID': 'HP000020'},
#  {'Name': 'Cough or Sputum', 'PID': 'OP000001'},
#  {'Name': 'Diarrhea', 'PID': 'OP000002'},
#  {'Name': 'Dyspnea', 'PID': 'OP000003'},
#  {'Name': 'Fever', 'PID': 'OP000004'},
#  {'Name': 'Headache or Headache disorder', 'PID': 'OP000005'},
#  {'Name': 'Altered smell or taste including Anosmia, Hyposmia or Dysgeusia',
#   'PID': 'OP000006'},
#  {'Name': 'Sore throat', 'PID': 'OP000007'},
#  {'Name': 'Nausea or Vomiting', 'PID': 'OP000008'},
#  {'Name': 'Malaise and or fatigue', 'PID': 'OP000009'},
#  {'Name': 'Rhinitis or common cold or Sinusitis', 'PID': 'OP000010'},
#  {'Name': 'Myalgia (not explained by injury, ischemia or systemic inflammation)',
#   'PID': 'OP000011'},
#  {'Name': 'Myalgia', 'PID': 'OP000012'},
#  {'Name': 'Bronchitis or Bronchiolitis', 'PID': 'OP000013'},
#  {'Name': 'Acute respiratory distress syndrome (ARDS) or Acute Respiratory Failure',
#   'PID': 'OP000014'},
#  {'Name': 'Inpatient Hospitalization (1Pe, 0Era)', 'PID': 'OP000015'},
#  {'Name': 'Emergency room visits (0Pe, 0Era)', 'PID': 'OP000016'},
#  {'Name': 'All cause mortality', 'PID': 'OP000017'},
#  {'Name': 'Asthma without COPD', 'PID': 'OP000018'},
#  {'Name': 'Tuberculosis', 'PID': 'OP000019'},
#  {'Name': 'Malignant neoplasm excluding non-melanoma skin cancer',
#   'PID': 'OP000020'},
#  {'Name': 'Obesity', 'PID': 'OP000021'},
#  {'Name': 'Dementia', 'PID': 'OP000022'},
#  {'Name': 'Hypertensive disorder or hypertensive complications',
#   'PID': 'OP000023'},
#  {'Name': 'Human immunodeficiency virus (not HIV2) infection',
#   'PID': 'OP000024'},
#  {'Name': 'Hepatitis C infection, carrier status or antibody positivity',
#   'PID': 'OP000025'},
#  {'Name': 'Heart disease', 'PID': 'OP000026'},
#  {'Name': 'Diabetes Mellitus Type 2 or history of diabetes',
#   'PID': 'OP000027'},
#  {'Name': 'Respiratory or pulmonary tuberculosis', 'PID': 'OP000028'},
#  {'Name': 'Febrile seizure', 'PID': 'OP000029'},
#  {'Name': 'SARS-CoV-2 test (1pos) or COVID-19 diagnosis with (0 neg -3d to 3d)',
#   'PID': 'OP000030'},
#  {'Name': 'Bradycardia or heart block with inpatient admission',
#   'PID': 'OP000031'},
#  {'Name': 'Transverse myelitis or symptoms indexed on symptoms or diagnosis (1Ps, 0Era, 365W)',
#   'PID': 'OP000032'},
#  {'Name': 'Composite Flu-like symptoms fever, cough, malaise, fatigue, dyspnea, myalgia',
#   'PID': 'OP000033'},
#  {'Name': 'Stroke (ischemic or hemorrhagic) with inpatient admission',
#   'PID': 'OP000034'},
#  {'Name': 'Acute myocardial infarction with inpatient admission',
#   'PID': 'OP000035'},
#  {'Name': 'Influenza diagnosis or positive test result', 'PID': 'OP000036'},
#  {'Name': 'Hemorrhagic stroke (intracerebral bleeding) with inpatient admission',
#   'PID': 'OP000037'},
#  {'Name': 'Ischemic stroke with inpatient admission', 'PID': 'OP000038'},
#  {'Name': 'Transient ischemic attack with inpatient admission',
#   'PID': 'OP000039'},
#  {'Name': 'Gastrointestinal bleeding with inpatient admission',
#   'PID': 'OP000040'},
#  {'Name': 'Cardiac arrhythmia with inpatient admission', 'PID': 'OP000041'},
#  {'Name': 'Dialysis with inpatient admission', 'PID': 'OP000042'},
#  {'Name': 'Extracorporeal Membrane Oxygenation with inpatient admission',
#   'PID': 'OP000043'},
#  {'Name': 'Cesarean section', 'PID': 'OP000044'},
#  {'Name': 'Intensive services during hospitalization', 'PID': 'OP000045'},
#  {'Name': 'SARS-CoV-2 test (1pos) or COVID-19 diagnosis with (1pos or 0 neg 0d to 3d)',
#   'PID': 'OP000046'},
#  {'Name': 'Delirium', 'PID': 'OP000047'},
#  {'Name': 'Systemic lupus erythematosus indexed on signs, symptoms, treatment, or diagnosis (FP)',
#   'PID': 'OP000048'},
#  {'Name': 'Suicide attempt or self inflicted injury', 'PID': 'OP000049'},
#  {'Name': 'Attention Deficit Hyperactivity Disorder indexed on diagnosis or treatment',
#   'PID': 'OP000050'},
#  {'Name': 'Earliest of ST elevated Myocardial infarction or Acute MI with ST elevation',
#   'PID': 'OP000051'},
#  {'Name': 'Fatigue, Asthenia, Malaise, Lethargy, Anorexia', 'PID': 'OP000052'},
#  {'Name': 'Skin, Nasal or oral mucosal bleeding events often seen during thrombocytopenia',
#   'PID': 'OP000053'},
#  {'Name': 'Jaundice or Itching', 'PID': 'OP000054'},
#  {'Name': 'Encephalopathy or its presentations', 'PID': 'OP000055'},
#  {'Name': 'Primary or malignant urothelial bladder cancer', 'PID': 'OP000056'},
#  {'Name': 'Rheumatoid arthritis or complications', 'PID': 'OP000057'},
#  {'Name': 'Coronary Artery Disease from vessel disease to ischemic injury',
#   'PID': 'OP000058'},
#  {'Name': 'Crohns disease or its complication', 'PID': 'OP000059'},
#  {'Name': 'Major Depressive Disorder', 'PID': 'OP000060'},
#  {'Name': 'Psoriasis of skin', 'PID': 'OP000061'},
#  {'Name': 'Ulcerative colitis or complications', 'PID': 'OP000062'},
#  {'Name': 'Acquired Pure Red Cell Aplasia', 'PID': 'OP000063'},
#  {'Name': 'Febrile Neutropenia or Neutropenic Fever', 'PID': 'OP000064'},
#  {'Name': 'Hemolytic Anemia Extra corpuscular ex hgpathy, memb defect, g6pd',
#   'PID': 'OP000065'},
#  {'Name': 'Hemolytic Anemia Extra corpuscular ex hgpathy, memb defect',
#   'PID': 'OP000066'},
#  {'Name': 'Pancytopenia, Acquired', 'PID': 'OP000067'},
#  {'Name': 'Neutropenia or unspecified leukopenia', 'PID': 'OP000068'},
#  {'Name': 'Acquired Isolated Neutropenia or unspecified leukopenia',
#   'PID': 'OP000069'},
#  {'Name': 'Isolated Immune Thrombocytopenia', 'PID': 'OP000070'},
#  {'Name': 'Isolated Immune Thrombocytopenia in absence of common thrombocytopenia causes',
#   'PID': 'OP000071'},
#  {'Name': 'Rhabdomyolysis', 'PID': 'OP000072'},
#  {'Name': 'Sudden Cardiac arrest or cardiac death', 'PID': 'OP000073'},
#  {'Name': 'Angioedema', 'PID': 'OP000074'},
#  {'Name': 'Anaphylaxis Non Environmental exposure related', 'PID': 'OP000075'},
#  {'Name': 'Stevens-Johnson syndrome, toxic epidermal necrolysis spectrum',
#   'PID': 'OP000076'},
#  {'Name': 'Posterior reversible encephalopathy syndrome PRES',
#   'PID': 'OP000077'},
#  {'Name': 'Long QT Syndrome or QT prolonged (Acquired)', 'PID': 'OP000078'},
#  {'Name': 'Drug-induced Lupus', 'PID': 'OP000079'},
#  {'Name': 'Severe Cutaneous Adverse Reaction SCAR (SJS+TEN+DRESS+EM)',
#   'PID': 'OP000080'},
#  {'Name': 'Severe Cutaneous Adverse Reaction SCAR (SJS+TEN+DRESS)',
#   'PID': 'OP000081'},
#  {'Name': 'Progressive multifocal leukoencephalopathy', 'PID': 'OP000082'},
#  {'Name': 'Autoimmune hepatitis', 'PID': 'OP000083'},
#  {'Name': 'Paresthesia', 'PID': 'OP000084'},
#  {'Name': 'Hemorrhagic stroke', 'PID': 'OP000085'},
#  {'Name': 'Appendicitis (1Pe, 180Era)', 'PID': 'OP000086'},
#  {'Name': 'Guillain Barre syndrome inpatient', 'PID': 'OP000087'},
#  {'Name': 'Idiopathic Peripheral Neuropathy', 'PID': 'OP000088'},
#  {'Name': 'Kawasaki disease', 'PID': 'OP000089'},
#  {'Name': 'Narcolepsy events', 'PID': 'OP000090'},
#  {'Name': 'Muscle weakness or monoplegia', 'PID': 'OP000091'},
#  {'Name': 'Tinnitus', 'PID': 'OP000092'},
#  {'Name': 'Dizziness or giddiness including motion sickness and vertigo',
#   'PID': 'OP000093'},
#  {'Name': 'Hepatic Thrombosis', 'PID': 'OP000094'},
#  {'Name': 'Portal vein thrombosis', 'PID': 'OP000095'},
#  {'Name': 'Deep Vein Thrombosis DVT', 'PID': 'OP000096'},
#  {'Name': 'Disseminated intravascular coagulation DIC in inpatient visit',
#   'PID': 'OP000097'},
#  {'Name': 'Ischemic (Non-hemorrhagic) Stroke In Inpatient', 'PID': 'OP000098'},
#  {'Name': 'Acute pancreatitis', 'PID': 'OP000099'},
#  {'Name': 'Drug Induced Acute pancreatitis', 'PID': 'OP000100'},
#  {'Name': 'Drug Resistant Epilepsy', 'PID': 'OP000101'},
#  {'Name': "Alzheimer's disease (based on Imfeld, 2013)", 'PID': 'OP000102'},
#  {'Name': 'Facial Palsy lower motor neuron including Bells Palsy',
#   'PID': 'OP000103'},
#  {'Name': 'Emergency room visits or code', 'PID': 'OP000104'},
#  {'Name': 'Anaphylaxis or Anaphylactic shock events', 'PID': 'OP000105'},
#  {'Name': 'Anaphylaxis all cause', 'PID': 'OP000106'},
#  {'Name': 'ST elevated myocardial infarction with inpatient admission',
#   'PID': 'OP000107'},
#  {'Name': 'Non ST elevated myocardial infarction with inpatient admission',
#   'PID': 'OP000108'},
#  {'Name': 'Unstable Angina with inpatient admission', 'PID': 'OP000109'},
#  {'Name': 'Unstable Angina OR NSTEMI with inpatient admission',
#   'PID': 'OP000110'},
#  {'Name': 'Acute Hepatic Failure in persons with liver disease',
#   'PID': 'OP000111'},
#  {'Name': 'Drug Induced Acute Hepatic Failure', 'PID': 'OP000112'},
#  {'Name': 'Acute Kidney Injury AKI, in persons with chronic kidney disease',
#   'PID': 'OP000113'},
#  {'Name': 'Acute Kidney Injury AKI, in persons with NO chronic kidney disease',
#   'PID': 'OP000114'},
#  {'Name': 'Hemolytic Anemia', 'PID': 'OP000115'},
#  {'Name': 'Hemolytic Anemia Intra corpuscular', 'PID': 'OP000116'},
#  {'Name': 'Pathological Ventricular Tachycardia', 'PID': 'OP000117'},
#  {'Name': 'Cardiac arrest or Pathological Ventricular tachycardia',
#   'PID': 'OP000118'},
#  {'Name': 'Polymorphic Ventricular Tachycardia or Torsades de Pointes',
#   'PID': 'OP000119'},
#  {'Name': 'Sudden Vision Loss', 'PID': 'OP000120'},
#  {'Name': 'Sudden Hearing Loss', 'PID': 'OP000121'},
#  {'Name': 'Pain or ache that is Non Chronic', 'PID': 'OP000122'},
#  {'Name': 'Low Back Pain or injury', 'PID': 'OP000123'},
#  {'Name': 'Abdominal Pain or acute abdomen', 'PID': 'OP000124'},
#  {'Name': 'Epigastric Pain', 'PID': 'OP000125'},
#  {'Name': 'Joint Pain', 'PID': 'OP000126'},
#  {'Name': 'Prostatitis', 'PID': 'OP000127'},
#  {'Name': 'Myocarditis or Pericarditis', 'PID': 'OP000128'},
#  {'Name': 'Myocarditis or Pericarditis Not due to infections',
#   'PID': 'OP000129'},
#  {'Name': 'Transverse myelitis includes Myelitis Unspecified and neuromyelitis optica',
#   'PID': 'OP000130'},
#  {'Name': 'Type 2 Diabetes Mellitus indexed on diagnosis, treatment or lab results',
#   'PID': 'OP000131'},
#  {'Name': 'Presence Of Cardiac Arrhythmia', 'PID': 'OP000132'},
#  {'Name': 'Thyroiditis wo other causes of hypothy, indexed on diagnosis or treatment',
#   'PID': 'OP000133'},
#  {'Name': 'Gynecomastia, indexed on diagnosis, procedure or symptoms',
#   'PID': 'OP000134'},
#  {'Name': 'Hepatic Failure', 'PID': 'OP000135'},
#  {'Name': 'Acute Hepatic Injury with no chronic hepatic failure',
#   'PID': 'OP000136'},
#  {'Name': 'Acute Hepatic Injury with no pre-existing liver disease',
#   'PID': 'OP000137'},
#  {'Name': 'Acute Hepatic Failure in persons with no pre-existing liver disease',
#   'PID': 'OP000138'},
#  {'Name': 'Transverse myelitis or symptoms indexed on symptoms or diagnosis (180Pe, 180Era)',
#   'PID': 'OP000139'},
#  {'Name': 'Urinary bleed events in persons without renal glomerular disease',
#   'PID': 'OP000140'},
#  {'Name': 'Acute gastrointestinal bleeding or perforation events',
#   'PID': 'OP000141'},
#  {'Name': 'Heavy menstrual bleeding (menorrhagia) events', 'PID': 'OP000142'},
#  {'Name': 'Neurofibromatosis type 1 (FP)', 'PID': 'OP000143'},
#  {'Name': 'Neurofibromatosis type 1 without Type 2 (FP)', 'PID': 'OP000144'},
#  {'Name': 'Optical pathway glioma and neurofibromatosis (FP)',
#   'PID': 'OP000145'},
#  {'Name': 'Optical pathway glioma or non malignant neoplasm of optic nerve w neurofibromatosis',
#   'PID': 'OP000146'},
#  {'Name': 'Optical pathway glioma with MRI imaging and ophthalmology visits Neurofibromatosis',
#   'PID': 'OP000147'},
#  {'Name': 'Parasomnia', 'PID': 'OP000148'},
#  {'Name': 'Acute Hepatic Failure in persons without chronic hepatic failure on same day',
#   'PID': 'OP000149'},
#  {'Name': 'Pain', 'PID': 'OP000150'},
#  {'Name': 'Inpatient Hospitalization By Site of care or type of service',
#   'PID': 'OP000151'},
#  {'Name': 'Wheezing', 'PID': 'OP000152'},
#  {'Name': 'Encephalopathy', 'PID': 'OP000153'},
#  {'Name': 'Pain or ache that is Chronic', 'PID': 'OP000154'},
#  {'Name': 'Alcohol Use Disorder', 'PID': 'OP000155'},
#  {'Name': 'Asthma', 'PID': 'OP000156'},
#  {'Name': 'Anxiety or Fear', 'PID': 'OP000157'},
#  {'Name': 'Hives, Erythema, Eruption, Urticaria', 'PID': 'OP000158'},
#  {'Name': 'Loss of mentation including comma, syncope, altered consciousness',
#   'PID': 'OP000159'},
#  {'Name': 'Fecal Incontinence', 'PID': 'OP000160'},
#  {'Name': 'Doctors office or clinic visit without other overlapping visits',
#   'PID': 'OP000161'},
#  {'Name': 'Non urgent outpatient visit without overlapping inpatient or emergency visit',
#   'PID': 'OP000162'},
#  {'Name': 'Ambulance utilization', 'PID': 'OP000163'},
#  {'Name': 'Lower gastrointestinal bleeding events', 'PID': 'OP000164'},
#  {'Name': 'Nasal Polyp present', 'PID': 'OP000165'},
#  {'Name': 'Nasal Congestion or Rhinitis or Common Cold', 'PID': 'OP000166'},
#  {'Name': 'Laryngitis', 'PID': 'OP000167'},
#  {'Name': 'Epistaxis', 'PID': 'OP000168'},
#  {'Name': 'Acute Respiratory Failure among persons with no chronic respiratory failure',
#   'PID': 'OP000169'},
#  {'Name': 'Acute Respiratory Failure', 'PID': 'OP000170'},
#  {'Name': 'Pleural Effusion', 'PID': 'OP000171'},
#  {'Name': 'Acute Kidney Injury AKI', 'PID': 'OP000172'},
#  {'Name': 'Dysuria', 'PID': 'OP000173'},
#  {'Name': 'Streptococcal throat infection', 'PID': 'OP000174'},
#  {'Name': 'Allergic Rhinitis', 'PID': 'OP000175'},
#  {'Name': 'Allergic disorder', 'PID': 'OP000176'},
#  {'Name': 'Claudication Pain', 'PID': 'OP000177'},
#  {'Name': 'Otitis media', 'PID': 'OP000178'},
#  {'Name': 'Iron deficiency Anemia', 'PID': 'OP000179'},
#  {'Name': 'Gall stone disorder', 'PID': 'OP000180'},
#  {'Name': 'Ecchymosis', 'PID': 'OP000181'},
#  {'Name': 'Skin Itching', 'PID': 'OP000182'},
#  {'Name': 'Prurititc Rash', 'PID': 'OP000183'},
#  {'Name': 'Eczematous Atopic Dermatitis and non hyperkeratotic dermatosis',
#   'PID': 'OP000184'},
#  {'Name': 'Peripheral Neuropathy or Neuritits', 'PID': 'OP000185'},
#  {'Name': 'Hearing Loss', 'PID': 'OP000186'},
#  {'Name': 'Otalgia or Otitis', 'PID': 'OP000187'},
#  {'Name': 'Low Back Pain or Injury', 'PID': 'OP000188'},
#  {'Name': 'Gastroesophageal reflux disease', 'PID': 'OP000189'},
#  {'Name': 'Dysmenorrhea', 'PID': 'OP000190'},
#  {'Name': 'Bladder Outflow Obstruction', 'PID': 'OP000191'},
#  {'Name': 'Uterine Fibroids or benign uterine tumors', 'PID': 'OP000192'},
#  {'Name': 'Ventilatory assist for respiratory findings with Acute Respiratory Failure',
#   'PID': 'OP000193'},
#  {'Name': 'Acute Respiratory Failure in inpatient or Emergency room',
#   'PID': 'OP000194'},
#  {'Name': 'Ventricular Tachycardia, in an Inpatient or Emergency room setting',
#   'PID': 'OP000195'},
#  {'Name': 'Atrial Fibrillation or Flutter', 'PID': 'OP000196'},
#  {'Name': 'Acute Urinary tract infections UTI', 'PID': 'OP000197'},
#  {'Name': 'Sepsis or Septic Shock', 'PID': 'OP000198'},
#  {'Name': 'Transverse myelitis indexed on diagnosis (1Ps, 0Era, 365W)',
#   'PID': 'OP000199'},
#  {'Name': 'Acute Skin Eruption symptoms', 'PID': 'OP000200'},
#  {'Name': 'Skin Rash', 'PID': 'OP000201'},
#  {'Name': 'Acute gastrointestinal bleeding events', 'PID': 'OP000202'},
#  {'Name': 'Transverse myelitis or symptoms indexed on symptoms or diagnosis',
#   'PID': 'OP000203'},
#  {'Name': 'Transverse myelitis indexed on diagnosis', 'PID': 'OP000204'},
#  {'Name': 'Acquired Neutropenia or unspecified leukopenia', 'PID': 'OP000205'},
#  {'Name': 'Appendicitis during Inpatient visit', 'PID': 'OP000206'},
#  {'Name': 'Alanine aminotransferase (ALT) elevated', 'PID': 'OP000207'},
#  {'Name': 'Aspartate aminotransferase (AST) elevated', 'PID': 'OP000208'},
#  {'Name': 'Total Bilirubin elevated', 'PID': 'OP000209'},
#  {'Name': 'Prothrombin time (PT) elevated', 'PID': 'OP000210'},
#  {'Name': 'Inpatient Hospitalization (0Pe, 1Era)', 'PID': 'OP000211'},
#  {'Name': 'International normalized ratio (INR)', 'PID': 'OP000212'},
#  {'Name': 'Cirrhosis of liver or its sequela', 'PID': 'OP000213'},
#  {'Name': 'Viral hepatitis including history of', 'PID': 'OP000214'},
#  {'Name': 'Alcoholic hepatitis or alcohol liver disorder', 'PID': 'OP000215'},
#  {'Name': 'Hepatic fibrosis', 'PID': 'OP000216'},
#  {'Name': 'Acute Hepatic Injury', 'PID': 'OP000217'},
#  {'Name': 'Portal vein thrombosis', 'PID': 'OP000218'},
#  {'Name': 'Aplastic Anemia', 'PID': 'OP000219'},
#  {'Name': 'Sudden New Onset Blindness', 'PID': 'OP000220'},
#  {'Name': 'Endometriosis', 'PID': 'OP000221'},
#  {'Name': 'Earliest event of Acute Hepatic Failure', 'PID': 'OP000222'},
#  {'Name': 'Earliest event of Acute Hepatic Failure, NO viral hepatitis or alcoholic hepatic failure',
#   'PID': 'OP000223'},
#  {'Name': 'All events of Acute Kidney Injury (AKI)', 'PID': 'OP000224'},
#  {'Name': 'All events of Anaphylaxis, Mini-Sentinel', 'PID': 'OP000225'},
#  {'Name': 'Angioedema', 'PID': 'OP000226'},
#  {'Name': 'Autoimmune hemolytic anemia', 'PID': 'OP000227'},
#  {'Name': 'All events of Autoimmune hepatitis, with a washout period of 365 days',
#   'PID': 'OP000228'},
#  {'Name': 'All events Acute pancreatitis, indexed on visit with NO chronic or hereditary pancreatitis',
#   'PID': 'OP000229'},
#  {'Name': 'All events of Sudden Hearing Loss, No congenital anomaly or middle or inner ear conditions',
#   'PID': 'OP000230'},
#  {'Name': 'All events of Severe Cutaneous Adverse Reaction (SCAR = SJS+TEN+DRESS)',
#   'PID': 'OP000231'},
#  {'Name': 'All events Drug Rash with Eosinophilia and Systemic Symptoms (DRESS)',
#   'PID': 'OP000232'},
#  {'Name': 'All events Drug Rash with Eosinophilia and Systemic Symptoms (DRESS)',
#   'PID': 'OP000233'},
#  {'Name': 'All events of Acute Liver Injury', 'PID': 'OP000234'},
#  {'Name': 'All events of Acute Liver Injury, NO viral hepatitis or alcoholic hepatic failure',
#   'PID': 'OP000235'},
#  {'Name': 'Neutropenic Fever, Inpatient or ER, indexed on fever or Infection, 90 days era',
#   'PID': 'OP000236'},
#  {'Name': 'Autoimmune hemolytic anemia', 'PID': 'OP000237'},
#  {'Name': 'Isolated Immune Thrombocytopenia (ITP), with a washout period of 365 days',
#   'PID': 'OP000238'},
#  {'Name': 'Earliest event of Thrombotic microangiopathy (TMA) or Microangiopathic hemolytic anemia (MAHA)',
#   'PID': 'OP000239'},
#  {'Name': 'Parasomnia or Sleep dysfunction with arousal disturbance',
#   'PID': 'OP000240'},
#  {'Name': 'Diabetic ketoacidosis identified during the inpatient or emergency room SNOMED concept',
#   'PID': 'OP000241'},
#  {'Name': 'Pulmonary Hypertension', 'PID': 'OP000242'},
#  {'Name': 'Chronic Thromboembolic Pulmonary Hypertension', 'PID': 'OP000243'},
#  {'Name': 'Pulmonary Arterial Hypertension', 'PID': 'OP000244'},
#  {'Name': 'Psoriatic arthritis', 'PID': 'OP000245'},
#  {'Name': 'Plaque Psoriasis', 'PID': 'OP000246'},
#  {'Name': 'Pulmonary hypertension associated with left heart disease (WHO Group 2)',
#   'PID': 'OP000247'},
#  {'Name': 'Firearm Accidents (FA)', 'PID': 'OP000248'},
#  {'Name': 'Motor Vehicle Accidents (MVA)', 'PID': 'OP000249'},
#  {'Name': 'Down Syndrome', 'PID': 'OP000250'},
#  {'Name': 'Non-infectious uveitis and iridocyclitis', 'PID': 'OP000251'},
#  {'Name': 'Cystic Fibrosis', 'PID': 'OP000252'},
#  {'Name': 'Concomitant TNF - alpha Inhibitors and IL12_23 Inhibitors - GE 30D overlap',
#   'PID': 'OP000253'},
#  {'Name': 'Concomitant TNF - alpha Inhibitors and IL23 Inhibitors - GE 30D overlap',
#   'PID': 'OP000254'},
#  {'Name': 'Concomitant IL 23 Inhibitors and IL12_23 Inhibitors - GE 30D overlap',
#   'PID': 'OP000255'},
#  {'Name': 'Pulmonary arterial hypertension with Prior Left Heart or Vice Versa',
#   'PID': 'OP000256'},
#  {'Name': 'Endothelin receptor antagonists', 'PID': 'OP000257'},
#  {'Name': 'Phosphodiesterase 5 inhibitors and guanylate cyclase stimulators',
#   'PID': 'OP000258'},
#  {'Name': 'Prostacyclin analogues and prostacyclin receptor agonists',
#   'PID': 'OP000259'},
#  {'Name': 'Left Heart Failure', 'PID': 'OP000260'},
#  {'Name': 'Right Heart Failure', 'PID': 'OP000261'},
#  {'Name': 'Sarcoidosis', 'PID': 'OP000262'},
#  {'Name': 'Sickle Cell Anemia', 'PID': 'OP000263'},
#  {'Name': 'Scleroderma', 'PID': 'OP000264'},
#  {'Name': 'Essential Hypertension', 'PID': 'OP000265'},
#  {'Name': 'Congenital Heart Disease', 'PID': 'OP000266'},
#  {'Name': 'Portal Hypertension', 'PID': 'OP000267'},
#  {'Name': 'Inflammatory Bowel Disease', 'PID': 'OP000268'},
#  {'Name': 'Antisynthetase syndrome', 'PID': 'OP000269'},
#  {'Name': 'Mixed connective tissue disease', 'PID': 'OP000270'},
#  {'Name': 'Undifferentiated connective tissue disease', 'PID': 'OP000271'},
#  {'Name': 'Overlap syndrome', 'PID': 'OP000272'},
#  {'Name': 'Raynaudâ€™s disease or Raynaudâ€™s phenomenon', 'PID': 'OP000273'},
#  {'Name': 'Antiphospholipid syndrome', 'PID': 'OP000274'},
#  {'Name': 'Chronic Thromboembolic Pulmonary Hypertension', 'PID': 'OP000275'},
#  {'Name': 'Pulmonary endarterectomy', 'PID': 'OP000276'},
#  {'Name': 'Balloon Pulmonary Angioplasty', 'PID': 'OP000277'},
#  {'Name': 'Skin Burns', 'PID': 'OP000278'},
#  {'Name': 'Breast cancer', 'PID': 'OP000279'},
#  {'Name': 'Glioblastoma multiforme (GBM)', 'PID': 'OP000280'},
#  {'Name': 'Colorectal Cancer', 'PID': 'OP000281'},
#  {'Name': 'Multiple Myeloma', 'PID': 'OP000282'},
#  {'Name': 'Metastatic Hormone-Sensitive Prostate Cancer Synchronous',
#   'PID': 'OP000283'},
#  {'Name': 'Metastatic Hormone-Sensitive Prostate Cancer Metachronus',
#   'PID': 'OP000284'},
#  {'Name': 'Hemorrhage of digestive system', 'PID': 'OP000285'},
#  {'Name': 'Antineoplastic drugs against colorectal cancer', 'PID': 'OP000286'},
#  {'Name': 'Potential curative surgery for colorectal cancer',
#   'PID': 'OP000287'},
#  {'Name': 'Radiotherapy against colorectal cancer', 'PID': 'OP000288'},
#  {'Name': 'Primary adenocarcinoma of the colon or rectum', 'PID': 'OP000289'},
#  {'Name': 'Acute Respiratory Failure', 'PID': 'OP000290'},
#  {'Name': 'Fascial dehiscence and evisceration', 'PID': 'OP000291'},
#  {'Name': 'Anastomotic leak or dehiscence', 'PID': 'OP000292'},
#  {'Name': 'Intestinal obstruction', 'PID': 'OP000293'},
#  {'Name': 'Intraabdominal abscess', 'PID': 'OP000294'},
#  {'Name': 'Perioperative aspiration', 'PID': 'OP000295'},
#  {'Name': 'Postoperative hemorrhage', 'PID': 'OP000296'},
#  {'Name': 'Surgical wound infection (narrow)', 'PID': 'OP000297'},
#  {'Name': 'Distant metastasis following colorectal cancer (wide)',
#   'PID': 'OP000298'},
#  {'Name': 'Local recurrence after colorectal cancer', 'PID': 'OP000299'},
#  {'Name': 'Primary adenocarcinoma of the colon or rectum, MSI-H or dMMR, no surgery or oncological treatment',
#   'PID': 'OP000300'},
#  {'Name': 'Primary adenocarcinoma of the colon or rectum treated with potentially curative surgery',
#   'PID': 'OP000301'},
#  {'Name': 'Primary adenocarcinoma of the colon or rectum, no curative intended surgery and oncological treatment',
#   'PID': 'OP000302'},
#  {'Name': 'Primary adenocarcinoma of the colon or rectum, no curative intended surgery and oncological treatment',
#   'PID': 'OP000303'},
#  {'Name': 'Primary adenocarcinoma of the colon or rectum, MSI-L, MSI-indeterminate, MSS or pMMR',
#   'PID': 'OP000304'},
#  {'Name': 'Primary adenocarcinoma of the colon or rectum, MSI-L, MSI-indeterminate, MSS or pMMR, treated with curative intended surgery',
#   'PID': 'OP000305'},
#  {'Name': 'Primary adenocarcinoma of the colon or rectum, MSI-L, MSI-indeterminate, MSS or pMMR, oncological treatment, no curative surgery',
#   'PID': 'OP000306'},
#  {'Name': 'Primary adenocarcinoma of the colon or rectum, MSI-L, MSI-indeterminate, MSS or pMMR, no surgery or oncological treatment',
#   'PID': 'OP000307'},
#  {'Name': 'Primary adenocarcinoma of colon or rectum, MSI-H or dMMR, surgical treatment',
#   'PID': 'OP000308'},
#  {'Name': 'Primary adenocarcinoma of colon or rectum, MSI-H or dMMR, oncological treatment no surgery',
#   'PID': 'OP000309'},
#  {'Name': 'Primary adenocarcinoma of colon or rectum, MSI-H or dMMR',
#   'PID': 'OP000310'},
#  {'Name': 'Primary adenocarcinoma of colon', 'PID': 'OP000311'},
#  {'Name': 'Primary adenocarcinoma of colon, no surgery or oncological treatment',
#   'PID': 'OP000312'},
#  {'Name': 'Primary adenocarcinoma of colon surgical treatment',
#   'PID': 'OP000313'},
#  {'Name': 'Primary adenocarcinoma of colon oncological treatment, no surgery',
#   'PID': 'OP000314'},
#  {'Name': 'Primary adenocarcinoma of colon, MSI-L, MSI-indeterminate, MSS or pMMR',
#   'PID': 'OP000315'},
#  {'Name': 'Primary adenocarcinoma of colon, MSI-L, MSI-indeterminate, MSS or pMMR, surgically treated',
#   'PID': 'OP000316'},
#  {'Name': 'Primary adenocarcinoma of colon MSI-L, MSI-indeterminate, MSS or pMMR, oncological treatment, no surgery',
#   'PID': 'OP000317'},
#  {'Name': 'Primary adenocarcinoma of colon MSI-L, MSI-indeterminate, MSS or pMMR, no surgery or oncological treatment',
#   'PID': 'OP000318'},
#  {'Name': 'Primary adenocarcinoma of colon MSI-H or dMMR', 'PID': 'OP000319'},
#  {'Name': 'Primary adenocarcinoma of colon MSI-H or dMMR, surgical treatment',
#   'PID': 'OP000320'},
#  {'Name': 'Primary adenocarcinoma of colon MSI-H or dMMR, oncological treatment, no surgery',
#   'PID': 'OP000321'},
#  {'Name': 'Primary adenocarcinoma of colon MSI-H or dMMR, no surgery or oncological treatment',
#   'PID': 'OP000322'},
#  {'Name': 'Primary adenocarcinoma of rectum', 'PID': 'OP000323'},
#  {'Name': 'Primary adenocarcinoma of rectum MSI-H or dMMR', 'PID': 'OP000324'},
#  {'Name': 'Primary adenocarcinoma of rectum, MSI-H or dMMR, no surgery or oncological treatment',
#   'PID': 'OP000325'},
#  {'Name': 'Primary adenocarcinoma of rectum MSI-H or dMMR, oncological treatment, no surgery',
#   'PID': 'OP000326'},
#  {'Name': 'Primary adenocarcinoma of rectum, MSI-H or dMMR, surgical treatment',
#   'PID': 'OP000327'},
#  {'Name': 'Primary adenocarcinoma of rectum, MSI-L, MSI-indeterminate, MSS or pMMR',
#   'PID': 'OP000328'},
#  {'Name': 'Primary adenocarcinoma of rectum MSI-L, MSI-indeterminate, MSS or pMMR, oncological treatment, no surgery',
#   'PID': 'OP000329'},
#  {'Name': 'Primary adenocarcinoma of rectum MSI-L, MSI-indeterminate, MSS or pMMR, no surgery and no oncological treatment',
#   'PID': 'OP000330'},
#  {'Name': 'Primary adenocarcinoma of rectum MSI-L, MSI-indeterminate, MSS or pMMR, treated with potentially curative surgery',
#   'PID': 'OP000331'},
#  {'Name': 'Primary adenocarcinoma of rectum oncological treatment, no surgery',
#   'PID': 'OP000332'},
#  {'Name': 'Primary adenocarcinoma of rectum surgical treatment',
#   'PID': 'OP000333'},
#  {'Name': 'Primary adenocarcinoma of rectum, no surgery or oncological treatment',
#   'PID': 'OP000334'},
#  {'Name': 'Intraabdominal obstruction', 'PID': 'OP000335'},
#  {'Name': 'Surgical wound infection (broad)', 'PID': 'OP000336'},
#  {'Name': 'Distant metastasis following colorectal cancer (medium)',
#   'PID': 'OP000337'},
#  {'Name': 'Distant metastasis following colorectal cancer (narrow)',
#   'PID': 'OP000338'},
#  {'Name': 'Earliest event of Migraine, including history of migraine',
#   'PID': 'OP000339'},
#  {'Name': 'Earliest event of Migraine', 'PID': 'OP000340'},
#  {'Name': 'Earliest event of Rheumatoid Arthritis', 'PID': 'OP000341'},
#  {'Name': 'Earliest event of Crohns disease', 'PID': 'OP000342'},
#  {'Name': 'Earliest event of Ulcerative colitis', 'PID': 'OP000343'},
#  {'Name': "Earliest event of Alzheimer's disease derived from Imfeld, 2",
#   'PID': 'OP000344'},
#  {'Name': 'Cognitive impairment, incident', 'PID': 'OP000345'},
#  {'Name': 'Earliest event of Dementia', 'PID': 'OP000346'},
#  {'Name': 'Major Non Cardiac Surgery, adults, inpt stay, no ED',
#   'PID': 'OP000347'},
#  {'Name': 'Abdominal Aortic Aneurysm repair, adults, inpt stay, no ED',
#   'PID': 'OP000348'},
#  {'Name': 'Lower Extremity Bypass, adults, inpt stay, no ED',
#   'PID': 'OP000349'},
#  {'Name': 'Carotid Endarterectomy, adults, inpt stay, no ED',
#   'PID': 'OP000350'},
#  {'Name': 'Lung Resection, adults, inpt stay, no ED', 'PID': 'OP000351'},
#  {'Name': 'Esophagectomy, adults, inpt stay, no ED', 'PID': 'OP000352'},
#  {'Name': 'Pancreatectomy, adults, inpt stay, no ED', 'PID': 'OP000353'},
#  {'Name': 'Colectomy, adults, inpt stay, no ED', 'PID': 'OP000354'},
#  {'Name': 'Cystectomy, adults, inpt stay, no ED', 'PID': 'OP000355'},
#  {'Name': 'Nephrectomy, adults, inpt stay, no ED', 'PID': 'OP000356'},
#  {'Name': 'Coronary Artery Bypass Graft, adults, inpt stay, no ED',
#   'PID': 'OP000357'},
#  {'Name': 'Cardiac Valve Surgery, adults, inpt stay, no ED',
#   'PID': 'OP000358'},
#  {'Name': 'Non-Emergent MNCS (age 18 or greater), post op Afib (parox)',
#   'PID': 'OP000359'},
#  {'Name': 'Major Non Cardiac Surgery, adults, inpt stay, no ED, post op new Afib',
#   'PID': 'OP000360'},
#  {'Name': 'Acute myocardial infarction events', 'PID': 'OP000361'},
#  {'Name': 'Persons with decreased libido', 'PID': 'OP000362'},
#  {'Name': 'Diarrhea events', 'PID': 'OP000363'},
#  {'Name': 'Gastrointestinal bleeding events', 'PID': 'OP000364'},
#  {'Name': 'Hyponatremia events', 'PID': 'OP000365'},
#  {'Name': 'Hypotension events', 'PID': 'OP000366'},
#  {'Name': 'Nausea events', 'PID': 'OP000367'},
#  {'Name': 'Stroke (ischemic or hemorrhagic) events', 'PID': 'OP000368'},
#  {'Name': 'Persons with vertigo', 'PID': 'OP000369'},
#  {'Name': 'Abdominal pain events', 'PID': 'OP000370'},
#  {'Name': 'Abnormal weight gain events', 'PID': 'OP000371'},
#  {'Name': 'Abnormal weight loss events', 'PID': 'OP000372'},
#  {'Name': 'Acute renal failure events', 'PID': 'OP000373'},
#  {'Name': 'Anaphylactoid reaction events', 'PID': 'OP000374'},
#  {'Name': 'Persons with anemia', 'PID': 'OP000375'},
#  {'Name': 'Persons with anxiety', 'PID': 'OP000376'},
#  {'Name': 'Persons with bradycardia', 'PID': 'OP000377'},
#  {'Name': 'Person with cardiac arrhythmia', 'PID': 'OP000378'},
#  {'Name': 'Total cardiovascular disease events (ischemic stroke, hemorrhagic stroke, heart failure, acute myocardial infarction or sudden cardiac death)',
#   'PID': 'OP000379'},
#  {'Name': 'Cardiovascular-related mortality', 'PID': 'OP000380'},
#  {'Name': 'Persons with chest pain or angina', 'PID': 'OP000381'},
#  {'Name': 'Persons with chronic kidney disease', 'PID': 'OP000382'},
#  {'Name': 'Coronary heart disease events (acute myocardial infarction or sudden cardiac death)',
#   'PID': 'OP000383'},
#  {'Name': 'Cough events', 'PID': 'OP000384'},
#  {'Name': 'Persons with dementia', 'PID': 'OP000385'},
#  {'Name': 'Persons with depression', 'PID': 'OP000386'},
#  {'Name': 'Edema events', 'PID': 'OP000387'},
#  {'Name': 'Persons with end stage renal disease', 'PID': 'OP000388'},
#  {'Name': 'Fall events', 'PID': 'OP000389'},
#  {'Name': 'Persons with gout', 'PID': 'OP000390'},
#  {'Name': 'Headache events', 'PID': 'OP000391'},
#  {'Name': 'Persons with heart failure', 'PID': 'OP000392'},
#  {'Name': 'Hemorrhagic stroke (intracerebral bleeding) events',
#   'PID': 'OP000393'},
#  {'Name': 'Persons with hepatic failure', 'PID': 'OP000394'},
#  {'Name': 'Hospitalization with heart failure events', 'PID': 'OP000395'},
#  {'Name': 'Hospitalization with preinfarction syndrome events',
#   'PID': 'OP000396'},
#  {'Name': 'Hyperkalemia events', 'PID': 'OP000397'},
#  {'Name': 'Hypokalemia events', 'PID': 'OP000398'},
#  {'Name': 'Hypomagnesemia events', 'PID': 'OP000399'},
#  {'Name': 'Persons with impotence', 'PID': 'OP000400'},
#  {'Name': 'Ischemic stroke events', 'PID': 'OP000401'},
#  {'Name': 'Persons with a malignant neoplasm other than non-melanoma skin cancer',
#   'PID': 'OP000402'},
#  {'Name': 'Persons with measured renal dysfunction', 'PID': 'OP000403'},
#  {'Name': 'Persons with neutropenia or agranulocytosis', 'PID': 'OP000404'},
#  {'Name': 'Rash events', 'PID': 'OP000405'},
#  {'Name': 'Rhabdomyolysis events', 'PID': 'OP000406'},
#  {'Name': 'Sudden cardiac death events in inpatient', 'PID': 'OP000407'},
#  {'Name': 'Syncope events', 'PID': 'OP000408'},
#  {'Name': 'Persons with thrombocytopenia', 'PID': 'OP000409'},
#  {'Name': 'Transient ischemic attack events', 'PID': 'OP000410'},
#  {'Name': 'Persons with type 2 diabetes mellitus', 'PID': 'OP000411'},
#  {'Name': 'Vomiting events', 'PID': 'OP000412'},
#  {'Name': 'Persons with chronic kidney disease with 2+ diagnoses across 30d or 2+ dialysis',
#   'PID': 'OP000413'},
#  {'Name': '3-point MACE', 'PID': 'OP000414'},
#  {'Name': '4-point MACE', 'PID': 'OP000415'},
#  {'Name': 'Glycemic control', 'PID': 'OP000416'},
#  {'Name': 'Hospitalization with heart failure indexed on hospitalization',
#   'PID': 'OP000417'},
#  {'Name': 'Coronary Vessel Revascularization', 'PID': 'OP000418'},
#  {'Name': 'Stroke (ischemic or hemorrhagic) in inpatient', 'PID': 'OP000419'},
#  {'Name': 'Acute pancreatitis2', 'PID': 'OP000420'},
#  {'Name': 'Bladder Cancer', 'PID': 'OP000421'},
#  {'Name': 'Bone Fracture', 'PID': 'OP000422'},
#  {'Name': 'Breast cancer Malignant tumor of breast', 'PID': 'OP000423'},
#  {'Name': 'Diabetic ketoacidosis with inpatient or ER visit',
#   'PID': 'OP000424'},
#  {'Name': 'Genitourinary infection', 'PID': 'OP000425'},
#  {'Name': 'Hypoglycemia', 'PID': 'OP000426'},
#  {'Name': 'Joint pain3', 'PID': 'OP000427'},
#  {'Name': 'Lower extremity amputation', 'PID': 'OP000428'},
#  {'Name': 'Nausea3', 'PID': 'OP000429'},
#  {'Name': 'Photosensitivity', 'PID': 'OP000430'},
#  {'Name': 'Renal Cancer', 'PID': 'OP000431'},
#  {'Name': 'Thyroid tumor', 'PID': 'OP000432'},
#  {'Name': 'Venous thromboembolism', 'PID': 'OP000433'},
#  {'Name': 'Vomiting', 'PID': 'OP000434'},
#  {'Name': 'Earliest event of Epilepsy', 'PID': 'OP000435'},
#  {'Name': 'Earliest event of Treatment resistant depression (TRD)',
#   'PID': 'OP000436'},
#  {'Name': 'Earliest event of Chronic Graft Versus Host Disease (GVHD)',
#   'PID': 'OP000437'},
#  {'Name': 'Earliest event of Marginal zone lymphoma', 'PID': 'OP000438'},
#  {'Name': 'Earliest event of Waldenstrom macroglobulinemia',
#   'PID': 'OP000439'},
#  {'Name': 'Earliest event of Ankylosing Spondylitis', 'PID': 'OP000440'},
#  {'Name': 'Earliest event of Polyarticular juvenile idiopathic arthritis (JIA)',
#   'PID': 'OP000441'},
#  {'Name': 'Earliest event of Neonatal Thrombocytopenia (NT), less than 1 year old',
#   'PID': 'OP000442'},
#  {'Name': 'Earliest event of Warm Autoimmune Hemolytic Anemia (wAIHA)',
#   'PID': 'OP000443'},
#  {'Name': 'All events of Hemolytic Disease Fetus and Newborn (HDFN), RhD type, with a pregnancy episode',
#   'PID': 'OP000444'},
#  {'Name': 'Earliest event of Major depressive disorder, with NO occurrence of certain psychiatric disorder',
#   'PID': 'OP000445'},
#  {'Name': 'Earliest event of Myasthenia Gravis, inpatient, 2nd diagnosis or treatment, age gte 18',
#   'PID': 'OP000446'},
#  {'Name': 'Earliest event of Depressive and Sleep Disorder',
#   'PID': 'OP000447'},
#  {'Name': 'Earliest Event of Depressive Disorder with Suicidal Ideation or Attempt Prevalent',
#   'PID': 'OP000448'},
#  {'Name': 'Earliest Event of Depressive Disorder with Anhedonia',
#   'PID': 'OP000449'},
#  {'Name': 'First event of Attention-deficit hyperactivity (ADHD) disorder or procedure',
#   'PID': 'OP000450'},
#  {'Name': 'Earliest Event of Multiple Sclerosis', 'PID': 'OP000451'},
#  {'Name': 'Earliest event of Chronic Leukocytic Leukemia', 'PID': 'OP000452'},
#  {'Name': 'Earliest event of Urothelial carcinoma', 'PID': 'OP000453'},
#  {'Name': 'Earliest event of Mantle Cell Lymphoma', 'PID': 'OP000454'},
#  {'Name': 'Earliest event of Prostate cancer, among adult males',
#   'PID': 'OP000455'},
#  {'Name': 'Earliest event of Coronary artery disease (CAD)',
#   'PID': 'OP000456'},
#  {'Name': 'Earliest event of Type 2 Diabetes Mellitus (DM), with no type 1 or secondary DM',
#   'PID': 'OP000457'},
#  {'Name': 'Earliest event of Human Immunodeficiency Virus I (HIV), with treatment, lab or 2nd diagnosis',
#   'PID': 'OP000458'},
#  {'Name': 'All events of Respiratory syncytial virus infection, with 30 days washout',
#   'PID': 'OP000459'},
#  {'Name': 'New users of Thiazide diuretics', 'PID': 'OP000460'},
#  {'Name': 'New users of Beta blockers', 'PID': 'OP000461'},
#  {'Name': 'New users of SGLT2 inhibitor', 'PID': 'OP000462'},
#  {'Name': 'New users of GLP-1 receptor antagonists', 'PID': 'OP000463'},
#  {'Name': 'New users of DPP-4 inhibitors', 'PID': 'OP000464'},
#  {'Name': 'New users of Tumor Necrosis Factor alpha (TNFa) inhibitors',
#   'PID': 'OP000465'},
#  {'Name': 'New users of JAK inhibitors', 'PID': 'OP000466'},
#  {'Name': 'New users of IL-23 inhibitors', 'PID': 'OP000467'},
#  {'Name': 'New users of Fluoroquinolone systemic', 'PID': 'OP000468'},
#  {'Name': 'New users of Cephalosporin systemetic', 'PID': 'OP000469'},
#  {'Name': 'New users of Trimethoprim systemetic', 'PID': 'OP000470'},
#  {'Name': 'New users of Thiazide diuretics nested in essential hypertension',
#   'PID': 'OP000471'},
#  {'Name': 'New users of dihydropyridine calcium channel blockers nested in essential hypertension',
#   'PID': 'OP000472'},
#  {'Name': 'New users of dihydropyridine calcium channel blockers',
#   'PID': 'OP000473'},
#  {'Name': 'New users of Beta blockers nested in essential hypertension',
#   'PID': 'OP000474'},
#  {'Name': 'New users of Beta blockers nested in Left Heart Failure',
#   'PID': 'OP000475'},
#  {'Name': 'New users of SGLT2 inhibitor nested in Left Heart Failure',
#   'PID': 'OP000476'},
#  {'Name': 'New users of Beta blockers nested in Acute Myocardial Infarction',
#   'PID': 'OP000477'},
#  {'Name': 'New users of GLP-1 receptor antagonists nested in Type 2 diabetes mellitus',
#   'PID': 'OP000478'},
#  {'Name': 'New users of SGLT2 inhibitor nested in Type 2 diabetes mellitus',
#   'PID': 'OP000479'},
#  {'Name': 'New users of DPP-4 inhibitors nested in Type 2 diabetes mellitus',
#   'PID': 'OP000480'},
#  {'Name': 'New users of GLP-1 receptor antagonists nested in obesity',
#   'PID': 'OP000481'},
#  {'Name': 'New users of IL-23 inhibitors nested in Plaque psoriasis',
#   'PID': 'OP000482'},
#  {'Name': 'New users of Tumor Necrosis Factor alpha (TNFa) inhibitors nested in Plaque psoriasis',
#   'PID': 'OP000483'},
#  {'Name': 'New users of Tumor Necrosis Factor alpha (TNFa) inhibitors nested in Psoriatic Arthritis',
#   'PID': 'OP000484'},
#  {'Name': 'New users of Fluoroquinolone systemic nested in Urinary Tract Infection',
#   'PID': 'OP000485'},
#  {'Name': 'New users of Cephalosporin systemetic nested in Urinary Tract Infection',
#   'PID': 'OP000486'},
#  {'Name': 'New users of Trimethoprim systemetic nested in Urinary Tract Infection',
#   'PID': 'OP000487'},
#  {'Name': 'New users of Fluoroquinolone systemic nested in Acute Typical Pneumonia',
#   'PID': 'OP000488'},
#  {'Name': 'New users of Cephalosporin systemetic nested in Acute Typical Pneumonia',
#   'PID': 'OP000489'},
#  {'Name': 'New users of Trimethoprim systemetic nested in Acute Typical Pneumonia',
#   'PID': 'OP000490'},
#  {'Name': 'New users of Tumor Necrosis Factor alpha (TNFa) inhibitors nested in Rheumatoid arthritis',
#   'PID': 'OP000491'},
#  {'Name': 'New users of JAK inhibitors nested in Ulcerative colitis',
#   'PID': 'OP000492'},
#  {'Name': 'New users of Tumor Necrosis Factor alpha (TNFa) inhibitors nested in Ulcerative colitis',
#   'PID': 'OP000493'},
#  {'Name': 'New users of Tumor Necrosis Factor alpha (TNFa) inhibitors nested in Crohns disease',
#   'PID': 'OP000494'},
#  {'Name': 'New users of JAK inhibitors nested in Rheumatoid arthritis',
#   'PID': 'OP000495'},
#  {'Name': 'persons at risk at start of year 2012-2022 with 365d prior observation',
#   'PID': 'OP000496'},
#  {'Name': 'Cytomegalovirus CMV Anterior Uveitis', 'PID': 'OP000497'},
#  {'Name': 'Serious Infection, opportunistic infections and other infections of interest event',
#   'PID': 'OP000498'},
#  {'Name': 'Serious Infection', 'PID': 'OP000499'},
#  {'Name': 'Narcolepsy', 'PID': 'OP000500'},
#  {'Name': 'Anaphylaxis', 'PID': 'OP000501'},
#  {'Name': 'Anaphylaxis v2', 'PID': 'OP000502'},
#  {'Name': 'Bells Palsy', 'PID': 'OP000503'},
#  {'Name': 'Encephalomyelitis', 'PID': 'OP000504'},
#  {'Name': 'Guillain Barre Syndrome', 'PID': 'OP000505'},
#  {'Name': 'Acute Myocardial Infarction including its complications',
#   'PID': 'OP000506'},
#  {'Name': 'Myocarditis Pericarditis', 'PID': 'OP000507'},
#  {'Name': 'Immune Thrombocytopenia (ITP)', 'PID': 'OP000508'},
#  {'Name': 'Disseminated Intravascular Coagulation', 'PID': 'OP000509'},
#  {'Name': 'Appendicitis', 'PID': 'OP000510'},
#  {'Name': 'Transverse Myelitis', 'PID': 'OP000511'},
#  {'Name': 'Hemorrhagic Stroke', 'PID': 'OP000512'},
#  {'Name': 'Deep Vein Thrombosis (DVT)', 'PID': 'OP000513'},
#  {'Name': 'Non-hemorrhagic Stroke', 'PID': 'OP000514'},
#  {'Name': 'Pulmonary Embolism', 'PID': 'OP000515'},
#  {'Name': 'Thrombosis with Thrombocytopenia (TWT)', 'PID': 'OP000516'},
#  {'Name': 'Abdominal Aortic Aneurysm Repair, adults, inpt stay, no ED, post op new Afib',
#   'PID': 'OP000517'},
#  {'Name': 'Lower Extremity Bypass - post op new Afib', 'PID': 'OP000518'},
#  {'Name': 'Carotid Endarterectomy, adults, inpt stay, no ED, post op new Afib',
#   'PID': 'OP000519'},
#  {'Name': 'Esophagectomy, adults, inpt stay, no ED, post op new Afib',
#   'PID': 'OP000520'},
#  {'Name': 'Pancreatectomy, adults, inpt stay, no ED, post op new Afib',
#   'PID': 'OP000521'},
#  {'Name': 'Colectomy, adults, inpt stay, no ED, post op new Afib',
#   'PID': 'OP000522'},
#  {'Name': 'Cystectomy, adults, inpt stay, no ED, post op new Afib',
#   'PID': 'OP000523'},
#  {'Name': 'Nephrectomy, adults, inpt stay, no ED, post op new Afib',
#   'PID': 'OP000524'},
#  {'Name': 'Coronary Artery Bypass Graft Surgery, adults, inpt stay, no ED, post op new Afib',
#   'PID': 'OP000525'},
#  {'Name': 'Cardiac Valve Surgery, adults, inpt stay, no ED, post op new Afib',
#   'PID': 'OP000526'},
#  {'Name': 'RBC Transfusion (adult relevant, no auto 1yr clean window)',
#   'PID': 'OP000527'},
#  {'Name': 'Clostridium difficile - first episode', 'PID': 'OP000528'},
#  {'Name': 'Non-Emergent Major Non Cardiac Surgery no prior Opioid',
#   'PID': 'OP000529'},
#  {'Name': 'Emergency room visits (0Pe, 0Era)', 'PID': 'OP000530'},
#  {'Name': 'Autism', 'PID': 'OP000531'},
#  {'Name': 'Platinum based chemotherapy regimens', 'PID': 'OP000532'},
#  {'Name': 'Hyperlipidemia', 'PID': 'OP000533'},
#  {'Name': 'Hypoparathyroidism', 'PID': 'OP000534'},
#  {'Name': 'Osteoporosis', 'PID': 'OP000535'},
#  {'Name': 'Viral Hepatitis A', 'PID': 'OP000536'},
#  {'Name': 'Birdshot chorioretinitis', 'PID': 'OP000537'},
#  {'Name': 'CMV Anterior Uveitis sensitivite', 'PID': 'OP000538'},
#  {'Name': 'VZV Anterior Uveitis (SUN)', 'PID': 'OP000539'},
#  {'Name': 'VZV Anterior Uveitis (SUN) sensitive', 'PID': 'OP000540'},
#  {'Name': 'HSV Anterior Uveitis (SUN)', 'PID': 'OP000541'},
#  {'Name': 'HSV Anterior Uveitis (SUN) sensitive', 'PID': 'OP000542'},
#  {'Name': 'Behcet Uveitis (SUN)', 'PID': 'OP000543'},
#  {'Name': 'Sickle Cell Crisis', 'PID': 'OP000544'},
#  {'Name': 'Non Platinum chemotherapy regimen', 'PID': 'OP000545'},
#  {'Name': 'Acute Typical Pneumonia', 'PID': 'OP000546'},
#  {'Name': 'Asthma or Chronic obstructive pulmonary disease (COPD)',
#   'PID': 'OP000547'},
#  {'Name': 'Chronic obstructive pulmonary disease (COPD) without asthma',
#   'PID': 'OP000548'},
#  {'Name': 'Pneumonitis and lung infections', 'PID': 'OP000549'},
#  {'Name': 'Pulmonary hypertension associated with lung diseases and/or hypoxia (WHO Group 3)',
#   'PID': 'OP000550'},
#  {'Name': 'Non-small cell lung cancer (NSCLC)', 'PID': 'OP000551'},
#  {'Name': 'Lung cancer', 'PID': 'OP000552'},
#  {'Name': 'Lung Resection, adults, inpt stay, no ED, post op new Afib',
#   'PID': 'OP000553'},
#  {'Name': 'Pulmonary fibrosis', 'PID': 'OP000554'},
#  {'Name': 'Bladder cancer including history', 'PID': 'OP000555'},
#  {'Name': 'Chronic obstructive pulmonary disease (COPD)', 'PID': 'OP000556'},
#  {'Name': 'Chronic Interstitial lung disease (ILD) not including Acute Respiratory Distress Syndrome',
#   'PID': 'OP000557'},
#  {'Name': 'Lung Nodule', 'PID': 'OP000558'},
#  {'Name': 'Lung Nodule - solitary', 'PID': 'OP000559'},
#  {'Name': 'Lung Nodule - multiple', 'PID': 'OP000560'},
#  {'Name': 'Lung Mass (not acute, necrotic, atlectatic, abscess, fibrosis)',
#   'PID': 'OP000561'},
#  {'Name': 'Lung Lesion that is not acute, necrotic, atlectatic, abscess, fibrosis',
#   'PID': 'OP000562'},
#  {'Name': 'Stage 3 Non Small Cell Lung Cancer (NSCLC), indexed on lung abnormaility with no evidence of SCLC and had follow-up for NSCLC',
#   'PID': 'OP000563'},
#  {'Name': 'Non Small Cell Lung Cancer (NSCLC), indexed on lung abnormaility with no evidence of SCLC and had follow-up for NSCLC',
#   'PID': 'OP000564'},
#  {'Name': 'Small Cell Lung Cancer', 'PID': 'OP000565'},
#  {'Name': 'Primary Lung Cancer, indexed on lung abnormaility',
#   'PID': 'OP000566'},
#  {'Name': 'Hoarseness', 'PID': 'OP000567'},
#  {'Name': 'Bone Pain', 'PID': 'OP000568'},
#  {'Name': 'Weight loss', 'PID': 'OP000569'},
#  {'Name': 'Acute Bronchitis', 'PID': 'OP000570'},
#  {'Name': 'Stage 3 Non Small Cell Lung Cancer (NSCLC), indexed on lung abnormaility with no evidence of SCLC and had follow-up for NSCLC',
#   'PID': 'OP000571'},
#  {'Name': 'Intestinal obstruction - colorectal specific', 'PID': 'OP000572'},
#  {'Name': 'Intraabdominal abscess - narrow for colorectal cancer',
#   'PID': 'OP000573'},
#  {'Name': 'Major Non Cardiac Surgery, adults', 'PID': 'OP000574'},
#  {'Name': 'Abdominal Aortic Aneurysm repair, adults', 'PID': 'OP000575'},
#  {'Name': 'Lower Extremity Bypass, adults', 'PID': 'OP000576'},
#  {'Name': 'Carotid Endarterectomy, adults', 'PID': 'OP000577'},
#  {'Name': 'Lung Resection, adults', 'PID': 'OP000578'},
#  {'Name': 'Esophagectomy, adults', 'PID': 'OP000579'},
#  {'Name': 'Pancreatectomy, adults', 'PID': 'OP000580'},
#  {'Name': 'Colectomy, adults', 'PID': 'OP000581'},
#  {'Name': 'Cystectomy, adults', 'PID': 'OP000582'},
#  {'Name': 'Nephrectomy, adults', 'PID': 'OP000583'},
#  {'Name': 'Coronary Artery Bypass Graft, adults', 'PID': 'OP000584'},
#  {'Name': 'Cardiac Valve Surgery, adults', 'PID': 'OP000585'},
#  {'Name': 'Acute Urinary tract infections UTI', 'PID': 'OP000586'},
#  {'Name': 'Acute Heart failure', 'PID': 'OP000587'},
#  {'Name': 'Major Non Cardiac Surgery, adults, post op new Afib',
#   'PID': 'OP000588'},
#  {'Name': 'AAA repair, adults, post op new Afib', 'PID': 'OP000589'},
#  {'Name': 'Lower Extremity Bypass, adults, post op new Afib',
#   'PID': 'OP000590'},
#  {'Name': 'Carotid Endarterectomy, adults, post op new Afib',
#   'PID': 'OP000591'},
#  {'Name': 'Lung Resection, adults, post op new Afib', 'PID': 'OP000592'},
#  {'Name': 'Esophagectomy, adults, post op new Afib', 'PID': 'OP000593'},
#  {'Name': 'Pancreatectomy, adults, post op new Afib', 'PID': 'OP000594'},
#  {'Name': 'Colectomy, adults, post op new Afib', 'PID': 'OP000595'},
#  {'Name': 'Cystectomy, adults, post op new Afib', 'PID': 'OP000596'},
#  {'Name': 'Nephrectomy, adults, post op new Afib', 'PID': 'OP000597'},
#  {'Name': 'Coronary Artery Bypass Graft, adults, post op new Afib',
#   'PID': 'OP000598'},
#  {'Name': 'Cardiac Valve Surgery, adults, post op new Afib',
#   'PID': 'OP000599'},
#  {'Name': 'Abdominal Aortic Aneurysm ( AAA )', 'PID': 'PP000001'},
#  {'Name': 'ACE Inhibitor (ACE-I) induced cough', 'PID': 'PP000002'},
#  {'Name': 'Thromboembolic stroke', 'PID': 'SP000001'}]
